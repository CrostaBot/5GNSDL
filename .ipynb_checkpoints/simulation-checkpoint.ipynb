# %%
import matplotlib.pyplot as plt
import random as r
import pprint as pp
import numpy as np
import csv

# %%
# Define type of slice and its parameters
slices_type = {
    'eMBB' : {
        'bandwidth_max': 100000000, #max bandwidth which BS can give to this slice
        'client_weight': 0.3, # Portion of clients which use this type of slice
        'band_guaranteed' : 0, # based on quality of service
        'min': 4000000, 
        'max': 500000000 # how much bps can require this type of slice
      },
      'URLLC' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.2,
        'band_guaranteed' : 5000000,
        'min': 800,
        'max': 8000000
      },
      'MIoT' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.15,
        'band_guaranteed' : 1000000,
        'min': 800000, 
        'max': 8000000
      },
      'mMTC' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.15,
        'band_guaranteed' : 1000000,
        'min': 800000, 
        'max': 8000000
      },
      'voice' : {
        'bandwidth_max': 1000000,
        'client_weight': 0.2,
        'band_guaranteed' : 500000,
        'min': 4000000, 
        'max': 8000000
     }
}
          
# Define base station parameters
basestation = {
    'capacity': 20000000000,   #20Gbps
    'coverage': 250,
    'ratios': { # portion of capacity dedicated to various slice type
        'URLLC': 0.05,
        'eMBB': 0.55,
        'mMTC': 0.15,
        'voice': 0.1,
        'MIoT': 0.15
    },
    'x': 300,
    'y': 300
}

# Define mobility patterns and its parameters
mobility_patterns = {
  'car': {
    'distribution': 'normal',
    'params':(0,7),
    'client_weight': 0.10
  },
  'walk': {
    'distribution': 'randint',
    'params': (-1, 1),
    'client_weight': 0.40
  },
  'stationary': {
    'distribution': 'normal',
    'params': (0, 0.1),
    'client_weight': 0.20
  },
  'publictransport': {
    'distribution': 'randint',
    'params': (-4, 4),
    'client_weight': 0.10
  },
  'slackperson':{
    'distribution': 'randint',
    'params':(0, 1),
    'client_weight': 0.20
  }
}

# %%
# Define obj Client
class Client:
    def __init__(self, ID, x, y, mobility_pattern, freq, slice_type, bs, slice_cap = None):
        self.ID = ID
        self.x = x
        self.y = y
        self.mobility_pattern = mobility_pattern
        self.freq = freq
        self.slice_type = slice_type
        self.bs = bs
       #self.slice_cap = slice_cap
        self.usage_rem = 0
        self.last_usage = 0
        self.connected = False
        
        # stats
        self.tot_connected_time = 0
        self.tot_unconnected_time = 0
        self.tot_requests = 0
        self.consume_time = 0
        self.tot_usage = 0
        
    def step_1(self):
        if self.bs is not None:
            if self.usage_rem > 0:
                if self.connected:
                    self.start_consume()
                else:
                    self.connect()
            else:
                if self.connected:
                    self.disconnect()
                else:
                    self.generate_usage_and_connect()
        
    def step_2(self):
        if self.connected and self.last_usage > 0:
            self.release_consume()
            if self.usage_rem == 0:
                self.disconnect()
    
    def step_3(self):
        x, y = self.move()
        self.x += x
        self.y += y
        if self.bs is not None:
            if not inRange(self, bs):
                self.disconnect()       
                
    def generate_usage_and_connect(self):
        if self.slice_type is not None:
            # Generate new usage
            self.usage_rem = self.generate()
            self.tot_requests += 1
            self.connect()
            print(f"Client_{self.ID}, coordinates : ({self.x}, {self.y}) requests {self.usage_rem} usage to BS{self.bs.ID}")     

    def connect(self):
        s = self.slice_type
        if self.connected:
            return
        if self.is_avaliable():         # threshold for usage
            self.connected = True
            bs.connected_users += 1
            if s == 'eMBB':
                bs.embb_users += 1
            if s == 'URLLC':
                bs.urllc_users += 1
            if s == 'MIoT':
                bs.miot_users += 1
            if s == 'mMTC':
                bs.mmtc_users += 1
            if s == 'voice':
                bs.voice_users += 1
                
            print(f"Client {self.ID}, coordinates : ({self.x}, {self.y}) connected to slice {s} @ BS{self.bs.ID}")
            return True
        else:
            self.connected = False
            print(f"Client {self.ID}, coordinates : ({self.x}, {self.y}) connection refused to slice {s} @ BS{self.bs.ID}")
            return False
        
    def disconnect(self):
        s = self.slice_type
        if self.connected == True:
            bs.connected_users -= 1
            if s == 'eMBB':
                bs.embb_users -= 1
            if s == 'URLLC':
                bs.urllc_users -= 1
            if s == 'MIoT':
                bs.miot_users -= 1
            if s == 'mMTC':
                bs.mmtc_users -= 1
            if s == 'voice':
                bs.voice_users -= 1
            self.connected = False
            
        print(f"Client {self.ID}, coordinates: ({self.x},{self.y}) disconnected from slice {self.slice_type} @ BS{self.bs.ID} ")
        return not self.connected
    
    def start_consume(self):
        amount = min(self.usage_rem, self.get_consumable_share())    # bandwidth allocation
        bs.band_remaining -= amount  # BS allocate bandwidth and its capacity decreases
        #bs.pot_band_remaining -= amount
        self.last_usage = amount
        print(f"Client {self.ID}, coordinates: ({self.x}, {self.y}) gets {amount} usage from @ BS{self.bs.ID}")
           
    def release_consume(self):
        # release resources
        if self.last_usage > 0:
            bs.band_remaining += self.last_usage
            self.consume_time += 1
            self.tot_usage += self.last_usage
            self.usage_rem -= self.last_usage
            print(f"Client {self.ID}, coordinates: ({self.x}, {self.y}), releases {self.last_usage} usage to BS{self.bs.ID}")
            self.last_usage = 0
        
    # update client coordinates    
    def move(self):   
        distr = self.mobility_pattern.distribution
        params = self.mobility_pattern.params
        if distr == "randint":
            delta_x = r.randint(params[0], params[1])
            delta_y = r.randint(params[0], params[1])
            return delta_x, delta_y
        if distr == "normal":
            delta_x = np.random.normal(params[0], params[1])
            delta_y = np.random.normal(params[0], params[1])
            return delta_x, delta_y 
        
    # generate client consume   
    def generate(self):
        s = self.slice_type
        amount = r.randint(slices_type[s]['min'], slices_type[s]['max'])
        return amount
    
    def is_avaliable(self):
        global client_per_slice
        global new_capacity
        s = self.slice_type
        if s == 'eMBB':
            bandwidth_next = capacity[s] / (bs.embb_users + 1)
        if s == 'URLLC':
            bandwidth_next = capacity[s] / (bs.urllc_users + 1)
        if s == 'MIoT':
            bandwidth_next = capacity[s] / (bs.miot_users + 1)
        if s == 'mMTC':
            bandwidth_next = capacity[s] / (bs.mmtc_users + 1)
        if s == 'voice':
            bandwidth_next = capacity[s] / (bs.voice_users + 1)
       
        if bandwidth_next < slices_type[s]['band_guaranteed']:
            return False
        
        return True
      
    def get_consumable_share(self):
        global new_capacity
        s = self.slice_type

        if  s == 'eMBB' and bs.embb_users <= 0:
            return int(min(capacity[s], slices_type[s]['bandwidth_max']))
        else: 
            return int(min(capacity[s]/bs.embb_users, slices_type[s]['bandwidth_max']))
        if s == 'URLLC' and bs.urllc_users <= 0:
            return int(min(capacity[s], slices_type[s]['bandwidth_max']))
        else:
            return int(min(capacity[s]/bs.urllc_users, slices_type[s]['bandwidth_max']))
        if s == 'MIoT' and bs.miot_users <= 0:
            return int(min(capacity[s], slices_type[s]['bandwidth_max']))
        else:
            return int(min(capacity[s]/bs.miot_users, slices_type[s]['bandwidth_max']))
        if s == 'mMTC' and bs.mmtc_users <= 0:
            return int(min(capacity[s], slices_type[s]['bandwidth_max']))
        else: 
            return int(min(capacity[s]/bs.mmtc_users, slices_type[s]['bandwidth_max']))
        if s == 'voice' and bs.voice_users <= 0:
            return int(min(capacity[s], slices_type[s]['bandwidth_max']))
        else:
            return int(min(capacity[s]/bs.voice_users, slices_type[s]['bandwidth_max']))

# %%
# Define obj Mobility 
class Mobility:
    def __init__(self, name, distribution, params):
        self.name = name
        self.distribution = distribution
        self.params = params

# %%
# Define obj BaseStation
class BaseStation:
    def __init__(self,ID, x, y, coverage, capacity, ratios):
        self.ID =ID
        self.x = x
        self.y = y
        self.coverage = coverage
        self.capacity = capacity
        self.ratios = ratios
        self.pot_band_remaining = capacity
        self.band_remaining = capacity
        self.connected_users = 0
        self.embb_users = 0
        self.urllc_users = 0
        self.miot_users = 0
        self.mmtc_users = 0
        self.voice_users = 0

# %%
def get_random_mobility_pattern(vals, mobility_patterns):
    i = 0
    j = r.random()

    while vals[i] < j:
        i += 1

    return mobility_patterns[i]

def get_random_slice_type(vals):
    i = 0
    j = r.random()
    s = ''

    while vals[i] < j:
        i += 1
    
    if i == 0:
       s = 'eMBB'
    if i == 1:
       s = 'URLLC' 
    if i == 2:
       s = 'MIoT' 
    if i == 3:
       s = 'mMTC' 
    if i == 4:
       s = 'voice' 
    
    return s

def inRange(client, bs):
    x_client = client.x
    y_client = client.y
    x_bs = bs.x
    y_bs = bs.y
    if (abs(x_client - x_bs) < bs.coverage) and (abs(y_client - y_bs) < bs.coverage):
        return True
        print('true')
    else:
        return False
        print('false')

collected, slice_weights = 0, []
for key, value in slices_type.items():
    collected += value['client_weight']
    slice_weights.append(collected)

collected, mb_weights = 0, []
for key, value in mobility_patterns.items():
    collected += value['client_weight']
    mb_weights.append(collected)
    
m_patterns = []
for name, mb in mobility_patterns.items():
    mobility_pattern = Mobility(name, mb['distribution'], mb['params'])
    m_patterns.append(mobility_pattern)

# %%
# Define class Request
class Request:
    def __init__(self, id_client, type_slice, traffic_request, traffic_left):
        self.id_client = id_client
        self.type_slice = type_slice
        self.traffic_request = traffic_request
        self.traffic_left = traffic_left
        
#Define class csv
class CsvData:
    def __init__(self, step, r_embb, g_embb, connect_embb, r_urllc, g_urllc, connect_urllc, r_miot, g_miot, connect_miot, r_mmtc, g_mmtc, connect_mmtc, r_voice, g_voice, connect_voice):
        self.step = step
        self.r_embb = r_embb
        self.g_embb = g_embb
        self.connect_embb = connect_embb
        self.r_urllc = r_urllc
        self.g_urllc = g_urllc
        self.connect_urllc = connect_urllc
        self.r_miot = r_miot
        self.g_miot = g_miot
        self.connect_miot = connect_miot
        self.r_mmtc = r_mmtc
        self.g_mmtc = g_mmtc
        self.connect_mmtc = connect_mmtc
        self.r_voice = r_voice
        self.g_voice = g_voice
        self.connect_voice = connect_voice

# %%
# Round 0: create network area, place base station and clients
num_clients = 1000
simulation_time = 200
x_area = 600
y_area = 600

bs = BaseStation(0, basestation.get('x'), basestation.get('y'), basestation.get('coverage'), basestation.get('capacity'), basestation.get('ratios'))

clients = []
for i in range(num_clients):
    x = r.randint(0, x_area)
    y = r.randint(0, y_area)
    freq = r.random()
    
    mobility_pattern = get_random_mobility_pattern(mb_weights, m_patterns)
    slice_type = get_random_slice_type(slice_weights) 
    
    c = Client(i, x, y, mobility_pattern, freq, slice_type, bs)
    clients.append(c)

# %%
clients_inRange = []

for i in range(num_clients):
    if inRange(clients[i], bs):
        clients_inRange.append(clients[i])

# create fixed size list to manage the request
request_list = [None] * len(clients)
active_clients = []
csv_final = []

for n in range(simulation_time):
    bs.band_remaining = basestation.get('capacity')
    
    # manage number active clients
    active = []
    new_connection = r.randint(0, len(clients_inRange))
    active = r.sample(clients_inRange, new_connection)
    
    for j in range(len(active)):
        if request_list[active[j].ID] == None:
            active_clients.append(active[j])
    
    capacity = { 'eMBB' : 11000000000,
                 'URLLC' :1000000000,
                 'MIoT' : 3000000000,
                 'mMTC' : 3000000000,
                 'voice' : 2000000000
               }
    
    print('STEP', n)
    
    for i in range(len(active_clients)):   
        # step 1 and create request
        active_clients[i].step_1()
        
        req = Request(active_clients[i].ID, active_clients[i].slice_type, active_clients[i].usage_rem, active_clients[i].usage_rem)
        request_list[active_clients[i].ID] = req
        
    user_embb, user_urllc, user_miot, user_mmtc, user_voice = bs.embb_users, bs.urllc_users, bs.miot_users, bs.mmtc_users, bs.voice_users
  
    for i in range(len(active_clients)):
        # step 2 and update request (delete non active user, and update traffic)
        active_clients[i].step_2()
        request_list[active_clients[i].ID].traffic_left = active_clients[i].usage_rem
    
    req_embb, req_urllc, req_miot, req_mmtc, req_voice = 0, 0, 0, 0, 0
    giv_embb, giv_urllc, giv_miot, giv_mmtc, giv_voice = 0, 0, 0, 0, 0
    for item in request_list:
     if item is not None:
        if item.type_slice == 'eMBB':
            if item.traffic_request - item.traffic_left != 0:
                req_embb += item.traffic_request
                giv_embb += item.traffic_request - item.traffic_left 
            else:
                req_embb += 0
                giv_embb += 0
                
        if item.type_slice == 'URLLC' :
            if item.traffic_request - item.traffic_left != 0:
                req_urllc += item.traffic_request
                giv_urllc += item.traffic_request - item.traffic_left
            else:
                req_urllc += 0
                giv_urllc += 0
 
        if item.type_slice == 'MIoT':
            if item.traffic_request - item.traffic_left != 0:
                req_miot += item.traffic_request
                giv_miot += item.traffic_request - item.traffic_left
            else:
                req_miot += 0
                giv_miot += 0
 
        if item.type_slice == 'mMTC':
            if item.traffic_request - item.traffic_left != 0:
                req_mmtc += item.traffic_request
                giv_mmtc += item.traffic_request - item.traffic_left
            else:
                req_mmtc += 0
                giv_mmtc += 0

        if item.type_slice == 'voice':
            if item.traffic_request - item.traffic_left != 0:
                req_voice += item.traffic_request
                giv_voice += item.traffic_request - item.traffic_left
            else:
                req_voice += 0
                giv_voice += 0
    
    csv_data = CsvData(n, req_embb, giv_embb, user_embb, req_urllc, giv_urllc, user_urllc, req_miot, giv_miot, user_miot, req_mmtc, giv_mmtc, user_mmtc, req_voice, giv_voice, user_voice)  
    csv_final.append(csv_data)
    
    for i in range(len(active_clients)):
        if active_clients[i].connected == False:
            request_list[active_clients[i].ID] = None

    for item in active_clients:
        # step 3 and delete also user not in range
        item.step_3()
        if item.connected == False:
            request_list[item.ID] = None
            active_clients.remove(item)
# Out:
# STEP 0
# Client 751, coordinates : (92, 183) connected to slice mMTC @ BS0
# Client_751, coordinates : (92, 183) requests 6396297 usage to BS0
# Client 219, coordinates : (437, 311) connected to slice URLLC @ BS0
# Client_219, coordinates : (437, 311) requests 6547510 usage to BS0
# Client 620, coordinates : (215, 535) connected to slice URLLC @ BS0
# Client_620, coordinates : (215, 535) requests 4722564 usage to BS0
# Client 73, coordinates : (255, 403) connected to slice URLLC @ BS0
# Client_73, coordinates : (255, 403) requests 2515545 usage to BS0
# Client 297, coordinates : (306, 464) connected to slice voice @ BS0
# Client_297, coordinates : (306, 464) requests 7141503 usage to BS0
# Client 527, coordinates : (403, 509) connected to slice voice @ BS0
# Client_527, coordinates : (403, 509) requests 6475781 usage to BS0
# Client 823, coordinates : (285, 295) connected to slice URLLC @ BS0
# Client_823, coordinates : (285, 295) requests 1871184 usage to BS0
# Client 339, coordinates : (349, 422) connected to slice MIoT @ BS0
# Client_339, coordinates : (349, 422) requests 6955769 usage to BS0
# Client 100, coordinates : (425, 287) connected to slice eMBB @ BS0
# Client_100, coordinates : (425, 287) requests 321998932 usage to BS0
# Client 413, coordinates : (133, 434) connected to slice eMBB @ BS0
# Client_413, coordinates : (133, 434) requests 92323759 usage to BS0
# Client 674, coordinates : (438, 302) connected to slice MIoT @ BS0
# Client_674, coordinates : (438, 302) requests 6583377 usage to BS0
# Client 741, coordinates : (453, 203) connected to slice voice @ BS0
# Client_741, coordinates : (453, 203) requests 4124430 usage to BS0
# Client 711, coordinates : (392, 151) connected to slice mMTC @ BS0
# Client_711, coordinates : (392, 151) requests 6921475 usage to BS0
# Client 660, coordinates : (510, 541) connected to slice voice @ BS0
# Client_660, coordinates : (510, 541) requests 5946088 usage to BS0
# Client 571, coordinates : (390, 499) connected to slice eMBB @ BS0
# Client_571, coordinates : (390, 499) requests 154304355 usage to BS0
# Client 584, coordinates : (508, 83) connected to slice eMBB @ BS0
# Client_584, coordinates : (508, 83) requests 324941107 usage to BS0
# Client 438, coordinates : (386, 375) connected to slice eMBB @ BS0
# Client_438, coordinates : (386, 375) requests 456287639 usage to BS0
# Client 869, coordinates : (315, 193) connected to slice mMTC @ BS0
# Client_869, coordinates : (315, 193) requests 3492350 usage to BS0
# Client 977, coordinates : (188, 501) connected to slice eMBB @ BS0
# Client_977, coordinates : (188, 501) requests 169027739 usage to BS0
# Client 795, coordinates : (476, 446) connected to slice eMBB @ BS0
# Client_795, coordinates : (476, 446) requests 444784627 usage to BS0
# Client 85, coordinates : (446, 387) connected to slice mMTC @ BS0
# Client_85, coordinates : (446, 387) requests 7228449 usage to BS0
# Client 956, coordinates : (321, 164) connected to slice URLLC @ BS0
# Client_956, coordinates : (321, 164) requests 2054988 usage to BS0
# Client 682, coordinates : (246, 438) connected to slice eMBB @ BS0
# Client_682, coordinates : (246, 438) requests 43831415 usage to BS0
# Client 870, coordinates : (298, 442) connected to slice eMBB @ BS0
# Client_870, coordinates : (298, 442) requests 132515427 usage to BS0
# Client 835, coordinates : (322, 317) connected to slice eMBB @ BS0
# Client_835, coordinates : (322, 317) requests 106409451 usage to BS0
# Client 402, coordinates : (331, 422) connected to slice voice @ BS0
# Client_402, coordinates : (331, 422) requests 6525510 usage to BS0
# Client 68, coordinates : (215, 108) connected to slice eMBB @ BS0
# Client_68, coordinates : (215, 108) requests 183092913 usage to BS0
# Client 872, coordinates : (286, 502) connected to slice eMBB @ BS0
# Client_872, coordinates : (286, 502) requests 161425807 usage to BS0
# Client 846, coordinates : (503, 293) connected to slice eMBB @ BS0
# Client_846, coordinates : (503, 293) requests 337335029 usage to BS0
# Client 190, coordinates : (439, 544) connected to slice eMBB @ BS0
# Client_190, coordinates : (439, 544) requests 63162578 usage to BS0
# Client 807, coordinates : (245, 288) connected to slice voice @ BS0
# Client_807, coordinates : (245, 288) requests 7166198 usage to BS0
# Client 709, coordinates : (520, 468) connected to slice eMBB @ BS0
# Client_709, coordinates : (520, 468) requests 18368168 usage to BS0
# Client 430, coordinates : (192, 192) connected to slice MIoT @ BS0
# Client_430, coordinates : (192, 192) requests 1937146 usage to BS0
# Client 139, coordinates : (157, 124) connected to slice voice @ BS0
# Client_139, coordinates : (157, 124) requests 4736631 usage to BS0
# Client 33, coordinates : (137, 383) connected to slice MIoT @ BS0
# Client_33, coordinates : (137, 383) requests 4372106 usage to BS0
# Client 298, coordinates : (201, 59) connected to slice URLLC @ BS0
# Client_298, coordinates : (201, 59) requests 7903723 usage to BS0
# Client 2, coordinates : (436, 113) connected to slice voice @ BS0
# Client_2, coordinates : (436, 113) requests 6964073 usage to BS0
# Client 127, coordinates : (376, 189) connected to slice mMTC @ BS0
# Client_127, coordinates : (376, 189) requests 2514811 usage to BS0
# Client 301, coordinates : (283, 485) connected to slice mMTC @ BS0
# Client_301, coordinates : (283, 485) requests 1554946 usage to BS0
# Client 136, coordinates : (515, 139) connected to slice URLLC @ BS0
# Client_136, coordinates : (515, 139) requests 6398181 usage to BS0
# Client 511, coordinates : (503, 116) connected to slice eMBB @ BS0
# Client_511, coordinates : (503, 116) requests 103551701 usage to BS0
# Client 896, coordinates : (255, 201) connected to slice eMBB @ BS0
# Client_896, coordinates : (255, 201) requests 364486279 usage to BS0
# Client 592, coordinates : (439, 177) connected to slice mMTC @ BS0
# Client_592, coordinates : (439, 177) requests 7172029 usage to BS0
# Client 939, coordinates : (167, 142) connected to slice eMBB @ BS0
# Client_939, coordinates : (167, 142) requests 329618589 usage to BS0
# Client 698, coordinates : (57, 231) connected to slice voice @ BS0
# Client_698, coordinates : (57, 231) requests 7259029 usage to BS0
# Client 447, coordinates : (189, 461) connected to slice eMBB @ BS0
# Client_447, coordinates : (189, 461) requests 225847553 usage to BS0
# Client 292, coordinates : (55, 485) connected to slice eMBB @ BS0
# Client_292, coordinates : (55, 485) requests 223596220 usage to BS0
# Client 326, coordinates : (416, 486) connected to slice eMBB @ BS0
# Client_326, coordinates : (416, 486) requests 334484069 usage to BS0
# Client 922, coordinates : (504, 273) connected to slice URLLC @ BS0
# Client_922, coordinates : (504, 273) requests 5303698 usage to BS0
# Client 985, coordinates : (135, 123) connected to slice voice @ BS0
# Client_985, coordinates : (135, 123) requests 4540931 usage to BS0
# Client 58, coordinates : (520, 413) connected to slice eMBB @ BS0
# Client_58, coordinates : (520, 413) requests 117297858 usage to BS0
# Client 799, coordinates : (531, 505) connected to slice voice @ BS0
# Client_799, coordinates : (531, 505) requests 4224971 usage to BS0
# Client 103, coordinates : (340, 247) connected to slice URLLC @ BS0
# Client_103, coordinates : (340, 247) requests 148383 usage to BS0
# Client 943, coordinates : (108, 349) connected to slice MIoT @ BS0
# Client_943, coordinates : (108, 349) requests 2465863 usage to BS0
# Client 315, coordinates : (402, 329) connected to slice eMBB @ BS0
# Client_315, coordinates : (402, 329) requests 473822420 usage to BS0
# Client 8, coordinates : (331, 334) connected to slice URLLC @ BS0
# Client_8, coordinates : (331, 334) requests 7426688 usage to BS0
# Client 166, coordinates : (170, 460) connected to slice eMBB @ BS0
# Client_166, coordinates : (170, 460) requests 220517660 usage to BS0
# Client 55, coordinates : (514, 244) connected to slice URLLC @ BS0
# Client_55, coordinates : (514, 244) requests 5200047 usage to BS0
# Client 333, coordinates : (186, 486) connected to slice eMBB @ BS0
# Client_333, coordinates : (186, 486) requests 259523825 usage to BS0
# Client 706, coordinates : (194, 147) connected to slice mMTC @ BS0
# Client_706, coordinates : (194, 147) requests 4504211 usage to BS0
# Client 528, coordinates : (235, 129) connected to slice eMBB @ BS0
# Client_528, coordinates : (235, 129) requests 362667104 usage to BS0
# Client 817, coordinates : (341, 101) connected to slice mMTC @ BS0
# Client_817, coordinates : (341, 101) requests 1146603 usage to BS0
# Client 732, coordinates : (196, 214) connected to slice eMBB @ BS0
# Client_732, coordinates : (196, 214) requests 416376848 usage to BS0
# Client 119, coordinates : (319, 116) connected to slice voice @ BS0
# Client_119, coordinates : (319, 116) requests 5762579 usage to BS0
# Client 149, coordinates : (467, 69) connected to slice MIoT @ BS0
# Client_149, coordinates : (467, 69) requests 3400121 usage to BS0
# Client 35, coordinates : (538, 479) connected to slice mMTC @ BS0
# Client_35, coordinates : (538, 479) requests 3421782 usage to BS0
# Client 10, coordinates : (384, 365) connected to slice mMTC @ BS0
# Client_10, coordinates : (384, 365) requests 2370289 usage to BS0
# Client 591, coordinates : (369, 145) connected to slice eMBB @ BS0
# Client_591, coordinates : (369, 145) requests 59967624 usage to BS0
# Client 875, coordinates : (405, 350) connected to slice mMTC @ BS0
# Client_875, coordinates : (405, 350) requests 3641964 usage to BS0
# Client 994, coordinates : (193, 526) connected to slice eMBB @ BS0
# Client_994, coordinates : (193, 526) requests 59717226 usage to BS0
# Client 313, coordinates : (164, 71) connected to slice URLLC @ BS0
# Client_313, coordinates : (164, 71) requests 999508 usage to BS0
# Client 563, coordinates : (504, 513) connected to slice eMBB @ BS0
# Client_563, coordinates : (504, 513) requests 89062315 usage to BS0
# Client 537, coordinates : (304, 369) connected to slice eMBB @ BS0
# Client_537, coordinates : (304, 369) requests 123596765 usage to BS0
# Client 758, coordinates : (331, 505) connected to slice MIoT @ BS0
# Client_758, coordinates : (331, 505) requests 6432058 usage to BS0
# Client 904, coordinates : (517, 242) connected to slice MIoT @ BS0
# Client_904, coordinates : (517, 242) requests 3466470 usage to BS0
# Client 646, coordinates : (352, 177) connected to slice eMBB @ BS0
# Client_646, coordinates : (352, 177) requests 475423156 usage to BS0
# Client 986, coordinates : (194, 98) connected to slice eMBB @ BS0
# Client_986, coordinates : (194, 98) requests 221266372 usage to BS0
# Client 107, coordinates : (92, 328) connected to slice eMBB @ BS0
# Client_107, coordinates : (92, 328) requests 360297236 usage to BS0
# Client 496, coordinates : (71, 431) connected to slice URLLC @ BS0
# Client_496, coordinates : (71, 431) requests 3273248 usage to BS0
# Client 276, coordinates : (154, 448) connected to slice URLLC @ BS0
# Client_276, coordinates : (154, 448) requests 7089536 usage to BS0
# Client 362, coordinates : (236, 433) connected to slice voice @ BS0
# Client_362, coordinates : (236, 433) requests 5748304 usage to BS0
# Client 568, coordinates : (448, 279) connected to slice mMTC @ BS0
# Client_568, coordinates : (448, 279) requests 7693158 usage to BS0
# Client 863, coordinates : (320, 202) connected to slice eMBB @ BS0
# Client_863, coordinates : (320, 202) requests 124389600 usage to BS0
# Client 89, coordinates : (405, 328) connected to slice mMTC @ BS0
# Client_89, coordinates : (405, 328) requests 1336166 usage to BS0
# Client 649, coordinates : (112, 514) connected to slice eMBB @ BS0
# Client_649, coordinates : (112, 514) requests 152704620 usage to BS0
# Client 789, coordinates : (461, 433) connected to slice URLLC @ BS0
# Client_789, coordinates : (461, 433) requests 7393696 usage to BS0
# Client 369, coordinates : (157, 272) connected to slice MIoT @ BS0
# Client_369, coordinates : (157, 272) requests 2497059 usage to BS0
# Client 759, coordinates : (177, 380) connected to slice eMBB @ BS0
# Client_759, coordinates : (177, 380) requests 185783649 usage to BS0
# Client 407, coordinates : (472, 96) connected to slice MIoT @ BS0
# Client_407, coordinates : (472, 96) requests 6835580 usage to BS0
# Client 140, coordinates : (422, 417) connected to slice eMBB @ BS0
# Client_140, coordinates : (422, 417) requests 274622274 usage to BS0
# Client 655, coordinates : (240, 314) connected to slice eMBB @ BS0
# Client_655, coordinates : (240, 314) requests 490314362 usage to BS0
# Client 714, coordinates : (52, 114) connected to slice voice @ BS0
# Client_714, coordinates : (52, 114) requests 6005535 usage to BS0
# Client 778, coordinates : (493, 398) connected to slice eMBB @ BS0
# Client_778, coordinates : (493, 398) requests 83427001 usage to BS0
# Client 203, coordinates : (270, 281) connected to slice URLLC @ BS0
# Client_203, coordinates : (270, 281) requests 2204107 usage to BS0
# Client 951, coordinates : (324, 370) connected to slice voice @ BS0
# Client_951, coordinates : (324, 370) requests 7371472 usage to BS0
# Client 11, coordinates : (90, 94) connected to slice eMBB @ BS0
# Client_11, coordinates : (90, 94) requests 420176176 usage to BS0
# Client 968, coordinates : (64, 98) connected to slice URLLC @ BS0
# Client_968, coordinates : (64, 98) requests 5677527 usage to BS0
# Client 397, coordinates : (519, 69) connected to slice URLLC @ BS0
# Client_397, coordinates : (519, 69) requests 3798567 usage to BS0
# Client 43, coordinates : (331, 360) connected to slice mMTC @ BS0
# Client_43, coordinates : (331, 360) requests 4957000 usage to BS0
# Client 948, coordinates : (493, 201) connected to slice MIoT @ BS0
# Client_948, coordinates : (493, 201) requests 3601901 usage to BS0
# Client 892, coordinates : (159, 323) connected to slice eMBB @ BS0
# Client_892, coordinates : (159, 323) requests 251525736 usage to BS0
# Client 931, coordinates : (507, 284) connected to slice URLLC @ BS0
# Client_931, coordinates : (507, 284) requests 2816621 usage to BS0
# Client 834, coordinates : (267, 281) connected to slice eMBB @ BS0
# Client_834, coordinates : (267, 281) requests 218795083 usage to BS0
# Client 749, coordinates : (128, 539) connected to slice URLLC @ BS0
# Client_749, coordinates : (128, 539) requests 1245487 usage to BS0
# Client 774, coordinates : (192, 96) connected to slice eMBB @ BS0
# Client_774, coordinates : (192, 96) requests 239153415 usage to BS0
# Client 515, coordinates : (375, 287) connected to slice voice @ BS0
# Client_515, coordinates : (375, 287) requests 7384094 usage to BS0
# Client 395, coordinates : (400, 74) connected to slice URLLC @ BS0
# Client_395, coordinates : (400, 74) requests 817361 usage to BS0
# Client 559, coordinates : (242, 480) connected to slice eMBB @ BS0
# Client_559, coordinates : (242, 480) requests 461392665 usage to BS0
# Client 573, coordinates : (434, 493) connected to slice URLLC @ BS0
# Client_573, coordinates : (434, 493) requests 2892979 usage to BS0
# Client 91, coordinates : (350, 350) connected to slice voice @ BS0
# Client_91, coordinates : (350, 350) requests 5096019 usage to BS0
# Client 806, coordinates : (282, 255) connected to slice voice @ BS0
# Client_806, coordinates : (282, 255) requests 4890922 usage to BS0
# Client 223, coordinates : (495, 360) connected to slice URLLC @ BS0
# Client_223, coordinates : (495, 360) requests 4033039 usage to BS0
# Client 152, coordinates : (52, 255) connected to slice MIoT @ BS0
# Client_152, coordinates : (52, 255) requests 5313583 usage to BS0
# Client 507, coordinates : (83, 58) connected to slice eMBB @ BS0
# Client_507, coordinates : (83, 58) requests 122261774 usage to BS0
# Client 703, coordinates : (462, 285) connected to slice URLLC @ BS0
# Client_703, coordinates : (462, 285) requests 4326022 usage to BS0
# Client 228, coordinates : (537, 172) connected to slice URLLC @ BS0
# Client_228, coordinates : (537, 172) requests 6228531 usage to BS0
# Client 803, coordinates : (508, 172) connected to slice mMTC @ BS0
# Client_803, coordinates : (508, 172) requests 1722463 usage to BS0
# Client 614, coordinates : (526, 219) connected to slice eMBB @ BS0
# Client_614, coordinates : (526, 219) requests 165851824 usage to BS0
# Client 71, coordinates : (339, 217) connected to slice eMBB @ BS0
# Client_71, coordinates : (339, 217) requests 38467124 usage to BS0
# Client 309, coordinates : (326, 430) connected to slice voice @ BS0
# Client_309, coordinates : (326, 430) requests 4072372 usage to BS0
# Client 975, coordinates : (314, 58) connected to slice voice @ BS0
# Client_975, coordinates : (314, 58) requests 6276053 usage to BS0
# Client 753, coordinates : (161, 200) connected to slice URLLC @ BS0
# Client_753, coordinates : (161, 200) requests 4862389 usage to BS0
# Client 935, coordinates : (89, 157) connected to slice eMBB @ BS0
# Client_935, coordinates : (89, 157) requests 248797534 usage to BS0
# Client 266, coordinates : (203, 121) connected to slice voice @ BS0
# Client_266, coordinates : (203, 121) requests 7762774 usage to BS0
# Client 113, coordinates : (424, 256) connected to slice voice @ BS0
# Client_113, coordinates : (424, 256) requests 4378428 usage to BS0
# Client 206, coordinates : (526, 321) connected to slice eMBB @ BS0
# Client_206, coordinates : (526, 321) requests 375107580 usage to BS0
# Client 386, coordinates : (325, 245) connected to slice mMTC @ BS0
# Client_386, coordinates : (325, 245) requests 3372396 usage to BS0
# Client 363, coordinates : (451, 298) connected to slice eMBB @ BS0
# Client_363, coordinates : (451, 298) requests 107467370 usage to BS0
# Client 929, coordinates : (97, 89) connected to slice eMBB @ BS0
# Client_929, coordinates : (97, 89) requests 138355214 usage to BS0
# Client 63, coordinates : (361, 301) connected to slice eMBB @ BS0
# Client_63, coordinates : (361, 301) requests 160329758 usage to BS0
# Client 491, coordinates : (476, 325) connected to slice mMTC @ BS0
# Client_491, coordinates : (476, 325) requests 2717503 usage to BS0
# Client 117, coordinates : (244, 210) connected to slice URLLC @ BS0
# Client_117, coordinates : (244, 210) requests 2196572 usage to BS0
# Client 924, coordinates : (190, 65) connected to slice voice @ BS0
# Client_924, coordinates : (190, 65) requests 6467610 usage to BS0
# Client 115, coordinates : (466, 186) connected to slice eMBB @ BS0
# Client_115, coordinates : (466, 186) requests 262422476 usage to BS0
# Client 596, coordinates : (421, 267) connected to slice mMTC @ BS0
# Client_596, coordinates : (421, 267) requests 5926937 usage to BS0
# Client 796, coordinates : (367, 99) connected to slice voice @ BS0
# Client_796, coordinates : (367, 99) requests 5577900 usage to BS0
# Client 409, coordinates : (339, 156) connected to slice eMBB @ BS0
# Client_409, coordinates : (339, 156) requests 445986067 usage to BS0
# Client 278, coordinates : (543, 173) connected to slice URLLC @ BS0
# Client_278, coordinates : (543, 173) requests 5748822 usage to BS0
# Client 927, coordinates : (431, 421) connected to slice voice @ BS0
# Client_927, coordinates : (431, 421) requests 7959860 usage to BS0
# Client 354, coordinates : (222, 375) connected to slice eMBB @ BS0
# Client_354, coordinates : (222, 375) requests 300619574 usage to BS0
# Client 657, coordinates : (144, 452) connected to slice mMTC @ BS0
# Client_657, coordinates : (144, 452) requests 948433 usage to BS0
# Client 702, coordinates : (525, 190) connected to slice voice @ BS0
# Client_702, coordinates : (525, 190) requests 5080984 usage to BS0
# Client 268, coordinates : (83, 420) connected to slice MIoT @ BS0
# Client_268, coordinates : (83, 420) requests 3556547 usage to BS0
# Client 328, coordinates : (243, 341) connected to slice voice @ BS0
# Client_328, coordinates : (243, 341) requests 7692448 usage to BS0
# Client 243, coordinates : (118, 509) connected to slice MIoT @ BS0
# Client_243, coordinates : (118, 509) requests 2321158 usage to BS0
# Client 187, coordinates : (172, 475) connected to slice eMBB @ BS0
# Client_187, coordinates : (172, 475) requests 9142729 usage to BS0
# Client 603, coordinates : (160, 193) connected to slice URLLC @ BS0
# Client_603, coordinates : (160, 193) requests 4934014 usage to BS0
# Client 325, coordinates : (317, 548) connected to slice mMTC @ BS0
# Client_325, coordinates : (317, 548) requests 5133786 usage to BS0
# Client 833, coordinates : (519, 99) connected to slice voice @ BS0
# Client_833, coordinates : (519, 99) requests 7520107 usage to BS0
# Client 188, coordinates : (318, 429) connected to slice eMBB @ BS0
# Client_188, coordinates : (318, 429) requests 70689515 usage to BS0
# Client 336, coordinates : (327, 99) connected to slice voice @ BS0
# Client_336, coordinates : (327, 99) requests 5319573 usage to BS0
# Client 296, coordinates : (136, 107) connected to slice URLLC @ BS0
# Client_296, coordinates : (136, 107) requests 7286106 usage to BS0
# Client 421, coordinates : (266, 417) connected to slice URLLC @ BS0
# Client_421, coordinates : (266, 417) requests 2965442 usage to BS0
# Client 193, coordinates : (492, 61) connected to slice MIoT @ BS0
# Client_193, coordinates : (492, 61) requests 7857678 usage to BS0
# Client 721, coordinates : (394, 289) connected to slice URLLC @ BS0
# Client_721, coordinates : (394, 289) requests 4947470 usage to BS0
# Client 901, coordinates : (510, 516) connected to slice URLLC @ BS0
# Client_901, coordinates : (510, 516) requests 3764225 usage to BS0
# Client 181, coordinates : (70, 387) connected to slice eMBB @ BS0
# Client_181, coordinates : (70, 387) requests 38886851 usage to BS0
# Client 678, coordinates : (83, 67) connected to slice voice @ BS0
# Client_678, coordinates : (83, 67) requests 4603202 usage to BS0
# Client 122, coordinates : (310, 251) connected to slice MIoT @ BS0
# Client_122, coordinates : (310, 251) requests 3946434 usage to BS0
# Client 510, coordinates : (69, 460) connected to slice mMTC @ BS0
# Client_510, coordinates : (69, 460) requests 3793506 usage to BS0
# Client 719, coordinates : (299, 231) connected to slice voice @ BS0
# Client_719, coordinates : (299, 231) requests 5642239 usage to BS0
# Client 612, coordinates : (119, 395) connected to slice voice @ BS0
# Client_612, coordinates : (119, 395) requests 6681980 usage to BS0
# Client 458, coordinates : (333, 480) connected to slice mMTC @ BS0
# Client_458, coordinates : (333, 480) requests 3329929 usage to BS0
# Client 442, coordinates : (114, 169) connected to slice mMTC @ BS0
# Client_442, coordinates : (114, 169) requests 2172383 usage to BS0
# Client 157, coordinates : (244, 428) connected to slice voice @ BS0
# Client_157, coordinates : (244, 428) requests 4128017 usage to BS0
# Client 254, coordinates : (95, 196) connected to slice voice @ BS0
# Client_254, coordinates : (95, 196) requests 6041715 usage to BS0
# Client 988, coordinates : (102, 540) connected to slice voice @ BS0
# Client_988, coordinates : (102, 540) requests 5627647 usage to BS0
# Client 361, coordinates : (146, 360) connected to slice voice @ BS0
# Client_361, coordinates : (146, 360) requests 4199016 usage to BS0
# Client 105, coordinates : (367, 224) connected to slice URLLC @ BS0
# Client_105, coordinates : (367, 224) requests 4582034 usage to BS0
# Client 973, coordinates : (490, 249) connected to slice eMBB @ BS0
# Client_973, coordinates : (490, 249) requests 108683325 usage to BS0
# Client 267, coordinates : (332, 499) connected to slice voice @ BS0
# Client_267, coordinates : (332, 499) requests 4377468 usage to BS0
# Client 613, coordinates : (196, 67) connected to slice URLLC @ BS0
# Client_613, coordinates : (196, 67) requests 1845842 usage to BS0
# Client 775, coordinates : (259, 169) connected to slice voice @ BS0
# Client_775, coordinates : (259, 169) requests 5982428 usage to BS0
# Client 259, coordinates : (282, 263) connected to slice eMBB @ BS0
# Client_259, coordinates : (282, 263) requests 123536218 usage to BS0
# Client 855, coordinates : (343, 257) connected to slice mMTC @ BS0
# Client_855, coordinates : (343, 257) requests 6655536 usage to BS0
# Client 382, coordinates : (384, 278) connected to slice eMBB @ BS0
# Client_382, coordinates : (384, 278) requests 409311991 usage to BS0
# Client 83, coordinates : (202, 360) connected to slice eMBB @ BS0
# Client_83, coordinates : (202, 360) requests 365005688 usage to BS0
# Client 615, coordinates : (434, 453) connected to slice URLLC @ BS0
# Client_615, coordinates : (434, 453) requests 1333511 usage to BS0
# Client 733, coordinates : (485, 374) connected to slice mMTC @ BS0
# Client_733, coordinates : (485, 374) requests 6200127 usage to BS0
# Client 842, coordinates : (470, 303) connected to slice URLLC @ BS0
# Client_842, coordinates : (470, 303) requests 4492866 usage to BS0
# Client 20, coordinates : (132, 164) connected to slice voice @ BS0
# Client_20, coordinates : (132, 164) requests 7750877 usage to BS0
# Client 770, coordinates : (182, 115) connected to slice URLLC @ BS0
# Client_770, coordinates : (182, 115) requests 501745 usage to BS0
# Client 466, coordinates : (124, 160) connected to slice eMBB @ BS0
# Client_466, coordinates : (124, 160) requests 25143988 usage to BS0
# Client 347, coordinates : (142, 181) connected to slice eMBB @ BS0
# Client_347, coordinates : (142, 181) requests 294148980 usage to BS0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-81d129ea8768> in <module>
#      38         request_list[active_clients[i].ID] = req
#      39
# ---> 40     user_embb, user_urllc, user_miot, user_mmtc, user_voice = bs.embb_users, bs.urllc_users, bs.miot_users, bs.mmtc_users, bs.voice.users
#      41
#      42     for i in range(len(active_clients)):
#
# AttributeError: 'BaseStation' object has no attribute 'voice'

# %%
with open('input.csv', mode='w') as csv_file:
    fieldnames = ['embb_rate', 'embb_users', 'embb_req', 'urllc_rate', 'urllc_users', 'urllc_req', 'miot_rate', 'miot_users', 'miot_req', 'mmtc_rate', 'mmtc_users', 'mmtc_req', 'voice_rate', 'voice_users', 'voice_req']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    writer.writeheader()
    for item in csv_final:
        writer.writerow({'embb_rate': item.g_embb, 'embb_users': item.connect_embb, 'embb_req': item.r_embb, 'urllc_rate': item.g_urllc, 'urllc_users': item.connect_urllc, 'urllc_req': item.r_urllc, 'miot_rate': item.g_miot, 'miot_users': item.connect_miot, 'miot_req': item.r_miot, 'mmtc_rate': item.g_mmtc, 'mmtc_users': item.connect_mmtc, 'mmtc_req': item.r_mmtc, 'voice_rate': item.g_voice, 'voice_users': item.connect_voice, 'voice_req': item.r_voice})

# %%
with open('input.csv', mode='w') as csv_file:
    fieldnames = ['embb_rate', 'embb_users', 'embb_req', 'urllc_rate', 'urllc_users', 'urllc_req', 'miot_rate', 'miot_users', 'miot_req', 'mmtc_rate', 'mmtc_users', 'mmtc_req', 'voice_rate', 'voice_users', 'voice_req']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
    writer.writeheader()
    for item in csv_final:
        writer.writerow({'embb_rate': item.g_embb, 'embb_users': item.connect_embb, 'embb_req': item.r_embb, 'urllc_rate': item.g_urllc, 'urllc_users': item.connect_urllc, 'urllc_req': item.r_urllc, 'miot_rate': item.g_miot, 'miot_users': item.connect_miot, 'miot_req': item.r_miot, 'mmtc_rate': item.g_mmtc, 'mmtc_users': item.connect_mmtc, 'mmtc_req': item.r_mmtc, 'voice_rate': item.g_voice, 'voice_users': item.connect_voice, 'voice_req': item.r_voice})

# %%
import copy
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import tikzplotlib
from statistics import mean
    
step = []
delta = []
mega = 1000000
band = bs.capacity/mega
rho = []
    
with open("input.csv", "r") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    next(csv_reader)
    next(csv_reader)
    for lines in csv_reader:
        rate_embb = int((int(lines[0])/mega))
    
        rate_urllc = int((int(lines[3])/mega))
        rate_miot = int((int(lines[6])/mega))
        rate_mmtc = int((int(lines[9])/mega))
        rate_voice = int((int(lines[12])/mega))
    
        rate_tot = rate_embb + rate_urllc + rate_miot + rate_mmtc + rate_voice
  
        rho.append(rate_tot/band)
        
rho = np.array(rho)

print(rho.mean()*100)
