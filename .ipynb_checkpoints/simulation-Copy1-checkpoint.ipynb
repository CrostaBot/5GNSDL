# %%
import matplotlib.pyplot as plt
import random as r
import pprint as pp
import numpy as np
import csv
import tensorflow as tf
from tensorflow import keras

# %%
# Define type of slice and its parameters
slices_type = {
    'eMBB' : {
        'bandwidth_max': 100000000, #max bandwidth which BS can give to this slice
        'client_weight': 0.3, # Portion of clients which use this type of slice
        'band_guaranteed' : 0, # based on quality of service
        'min': 4000000, 
        'max': 500000000 # how much bps can require this type of slice
      },
      'URLLC' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.2,
        'band_guaranteed' : 5000000,
        'min': 5000000,
        'max': 8000000
      },
      'MIoT' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.15,
        'band_guaranteed' : 1000000,
        'min': 1000000, 
        'max': 8000000
      },
      'mMTC' : {
        'bandwidth_max': 10000000,
        'client_weight': 0.15,
        'band_guaranteed' : 1000000,
        'min': 1000000, 
        'max': 8000000
      },
      'voice' : {
        'bandwidth_max': 1000000,
        'client_weight': 0.2,
        'band_guaranteed' : 500000,
        'min': 4000000, 
        'max': 8000000
     }
}
          
# Define base station parameters
basestation = {
    'capacity': 20000000000,   #20Gbps
    'coverage': 250,
    'ratios': { # portion of capacity dedicated to various slice type
        'URLLC': 0.05,
        'eMBB': 0.55,
        'mMTC': 0.15,
        'voice': 0.1,
        'MIoT': 0.15
    },
    'x': 300,
    'y': 300
}

# Define mobility patterns and its parameters
mobility_patterns = {
  'car': {
    'distribution': 'normal',
    'params':(0,7),
    'client_weight': 0.10
  },
  'walk': {
    'distribution': 'randint',
    'params': (-1, 1),
    'client_weight': 0.40
  },
  'stationary': {
    'distribution': 'normal',
    'params': (0, 0.1),
    'client_weight': 0.20
  },
  'publictransport': {
    'distribution': 'randint',
    'params': (-4, 4),
    'client_weight': 0.10
  },
  'slackperson':{
    'distribution': 'randint',
    'params':(0, 1),
    'client_weight': 0.20
  }
}

# %%
# Define obj Client
class Client:
    def __init__(self, ID, x, y, mobility_pattern, freq, slice_type, bs, slice_cap = None):
        self.ID = ID
        self.x = x
        self.y = y
        self.mobility_pattern = mobility_pattern
        self.freq = freq
        self.slice_type = slice_type
        self.bs = bs
        self.usage_rem = 0
        self.last_usage = 0
        self.connected = False
        
    def step_1(self):
        if self.bs is not None:
            if self.usage_rem > 0:
                if self.connected:
                    self.start_consume()
                else:
                    self.connect()
            else:
                if self.connected:
                    self.disconnect()
                else:
                    self.generate_usage_and_connect()
        
    def step_2(self):
        if self.connected and self.last_usage > 0:
            self.release_consume()
            if self.usage_rem == 0:
                self.disconnect()
    
    def step_3(self):
        x, y = self.move()
        self.x += x
        self.y += y
        if self.bs is not None:
            if not inRange(self, bs):
                self.disconnect()       
                
    def generate_usage_and_connect(self):
        if self.slice_type is not None:
            # Generate new usage
            self.usage_rem = self.generate()
            self.connect()
            print(f"Client_{self.ID}, coordinates : ({self.x}, {self.y}) requests {self.usage_rem} usage to BS{self.bs.ID} to slice {self.slice_type}")     

    def connect(self):
        s = self.slice_type
        
        if self.connected:
            return
        
        if self.is_avaliable():         # threshold for usage
            self.connected = True
            bs.connected_users += 1
            
            if s == 'eMBB':
                bs.embb_users += 1
            if s == 'URLLC':
                bs.urllc_users += 1
            if s == 'MIoT':
                bs.miot_users += 1
            if s == 'mMTC':
                bs.mmtc_users += 1
            if s == 'voice':
                bs.voice_users += 1
                
            print(f"Client {self.ID}, coordinates : ({self.x}, {self.y}) connected to slice {s} @ BS{self.bs.ID}")
        else:
            self.connected = False
            print(f"Client {self.ID}, coordinates : ({self.x}, {self.y}) connection refused to slice {s} @ BS{self.bs.ID}")
        
    def disconnect(self):
        s = self.slice_type
        
        if self.connected == True:
            
            bs.connected_users -= 1
            
            if s == 'eMBB':
                bs.embb_users -= 1
            if s == 'URLLC':
                bs.urllc_users -= 1
            if s == 'MIoT':
                bs.miot_users -= 1
            if s == 'mMTC':
                bs.mmtc_users -= 1
            if s == 'voice':
                bs.voice_users -= 1
                
            self.connected = False
            
        print(f"Client {self.ID}, coordinates: ({self.x},{self.y}) disconnected from slice {self.slice_type} @ BS{self.bs.ID} ")
    
    def start_consume(self):
        amount = min(self.usage_rem, self.get_consumable_share())    # bandwidth allocation
        self.last_usage = amount
        print(f"Client {self.ID}, coordinates: ({self.x}, {self.y}) gets {amount} usage from @ BS{self.bs.ID} for slice {self.slice_type}")
           
    def release_consume(self):
        # release resources
        if self.last_usage > 0:
            self.usage_rem -= self.last_usage
            print(f"Client {self.ID}, coordinates: ({self.x}, {self.y}), releases {self.last_usage} usage to BS{self.bs.ID}")
            self.last_usage = 0
        
    # update client coordinates    
    def move(self):   
        distr = self.mobility_pattern.distribution
        params = self.mobility_pattern.params
        if distr == "randint":
            delta_x = r.randint(params[0], params[1])
            delta_y = r.randint(params[0], params[1])
            return delta_x, delta_y
        if distr == "normal":
            delta_x = np.random.normal(params[0], params[1])
            delta_y = np.random.normal(params[0], params[1])
            return delta_x, delta_y 
        
    # generate client consume   
    def generate(self):
        s = self.slice_type
        cicciolina = r.randint(slices_type[s]['min'], slices_type[s]['max'])
        return cicciolina
    
    def is_avaliable(self):
        global capacity
        s = self.slice_type
        
        if s == 'eMBB':
            bandwidth_next = capacity[s] / (bs.embb_users + 1)
        if s == 'URLLC':
            bandwidth_next = capacity[s] / (bs.urllc_users + 1)
        if s == 'MIoT':
            bandwidth_next = capacity[s] / (bs.miot_users + 1)
        if s == 'mMTC':
            bandwidth_next = capacity[s] / (bs.mmtc_users + 1)
        if s == 'voice':
            bandwidth_next = capacity[s] / (bs.voice_users + 1)
       
        if bandwidth_next < slices_type[s]['band_guaranteed']:
            return False

        return True
      
    def get_consumable_share(self):
        global capacity
        s = self.slice_type

        if s == 'eMBB':
            if bs.embb_users <= 0:
                return int(min(capacity[s], slices_type[s]['bandwidth_max']))
            else: 
                return int(min(capacity[s]/bs.embb_users, slices_type[s]['bandwidth_max']))
        
        if s == 'URLLC':
            if bs.urllc_users <= 0:
                return int(min(capacity[s], slices_type[s]['bandwidth_max']))
            else:
                return int(min(capacity[s]/bs.urllc_users, slices_type[s]['bandwidth_max']))
        
        if s == 'MIoT':
            if bs.miot_users <= 0:
                return int(min(capacity[s], slices_type[s]['bandwidth_max']))
            else:
                return int(min(capacity[s]/bs.miot_users, slices_type[s]['bandwidth_max']))
        
        if s == 'mMTC':
            if bs.mmtc_users <= 0:
                return int(min(capacity[s], slices_type[s]['bandwidth_max']))
            else: 
                return int(min(capacity[s]/bs.mmtc_users, slices_type[s]['bandwidth_max']))
        
        if s == 'voice':
            if bs.voice_users <= 0:
                return int(min(capacity[s], slices_type[s]['bandwidth_max']))
            else:
                return int(min(capacity[s]/bs.voice_users, slices_type[s]['bandwidth_max']))

# %%
# Define obj Mobility 
class Mobility:
    def __init__(self, name, distribution, params):
        self.name = name
        self.distribution = distribution
        self.params = params

# %%
# Define obj BaseStation
class BaseStation:
    def __init__(self,ID, x, y, coverage, capacity, ratios):
        self.ID =ID
        self.x = x
        self.y = y
        self.coverage = coverage
        self.capacity = capacity
        self.ratios = ratios
        self.pot_band_remaining = capacity
        self.band_remaining = capacity
        self.connected_users = 0
        self.embb_users = 0
        self.urllc_users = 0
        self.miot_users = 0
        self.mmtc_users = 0
        self.voice_users = 0

# %%
def get_random_mobility_pattern(vals, mobility_patterns):
    i = 0
    j = r.random()

    while vals[i] < j:
        i += 1

    return mobility_patterns[i]

def get_random_slice_type(vals):
    i = 0
    j = r.random()
    s = ''

    while vals[i] < j:
        i += 1
    
    if i == 0:
       s = 'eMBB'
    if i == 1:
       s = 'URLLC' 
    if i == 2:
       s = 'MIoT' 
    if i == 3:
       s = 'mMTC' 
    if i == 4:
       s = 'voice' 
    
    return s

def inRange(client, bs):
    x_client = client.x
    y_client = client.y
    x_bs = bs.x
    y_bs = bs.y
    if (abs(x_client - x_bs) < bs.coverage) and (abs(y_client - y_bs) < bs.coverage):
        return True
        print('true')
    else:
        return False
        print('false')
        
def get_new_ratios(prediction):
    band = basestation.get('capacity')
    
    # Compute new cpacity
    embb = int(prediction[0]*band)
    urllc = int(prediction[1]*band)
    miot = int(prediction[2]*band)
    mmtc = int(prediction[3]*band)
    voice = int(prediction[4]*band)

    out = { 'eMBB': embb,
            'URLLC': urllc,
            'MIoT': miot,
            'mMTC': mmtc,
            'voice': voice
          }
    
    return out

collected, slice_weights = 0, []
for key, value in slices_type.items():
    collected += value['client_weight']
    slice_weights.append(collected)

collected, mb_weights = 0, []
for key, value in mobility_patterns.items():
    collected += value['client_weight']
    mb_weights.append(collected)
    
m_patterns = []
for name, mb in mobility_patterns.items():
    mobility_pattern = Mobility(name, mb['distribution'], mb['params'])
    m_patterns.append(mobility_pattern)   

# Load RNN
model = tf.keras.models.load_model('model.h5')

# %%
# Define class Request
class Request:
    def __init__(self, id_client, type_slice, traffic_request, traffic_left):
        self.id_client = id_client
        self.type_slice = type_slice
        self.traffic_request = traffic_request
        self.traffic_left = traffic_left
        
#Define class csv
class CsvData:
    def __init__(self, step, r_embb, g_embb, connect_embb, r_urllc, g_urllc, connect_urllc, r_miot, g_miot, connect_miot, r_mmtc, g_mmtc, connect_mmtc, r_voice, g_voice, connect_voice):
        self.step = step
        self.r_embb = r_embb
        self.g_embb = g_embb
        self.connect_embb = connect_embb
        self.r_urllc = r_urllc
        self.g_urllc = g_urllc
        self.connect_urllc = connect_urllc
        self.r_miot = r_miot
        self.g_miot = g_miot
        self.connect_miot = connect_miot
        self.r_mmtc = r_mmtc
        self.g_mmtc = g_mmtc
        self.connect_mmtc = connect_mmtc
        self.r_voice = r_voice
        self.g_voice = g_voice
        self.connect_voice = connect_voice

# %%
# Round 0: create network area, place base station and clients
num_clients = 1000
simulation_time = 30
x_area = 600
y_area = 600

bs = BaseStation(0, basestation.get('x'), basestation.get('y'), basestation.get('coverage'), basestation.get('capacity'), basestation.get('ratios'))

clients = []
for i in range(num_clients):
    x = r.randint(0, x_area)
    y = r.randint(0, y_area)
    freq = r.random()
    
    mobility_pattern = get_random_mobility_pattern(mb_weights, m_patterns)
    slice_type = get_random_slice_type(slice_weights) 
    
    c = Client(i, x, y, mobility_pattern, freq, slice_type, bs)
    clients.append(c)

# %%
clients_inRange = []

for i in range(num_clients):
    if inRange(clients[i], bs):
        clients_inRange.append(clients[i])

# create fixed size list to manage the request
request_list = [None] * len(clients)
active_clients = []
csv_final = []
capacity = { 'eMBB' : 11000000000,
             'URLLC' :1000000000,
             'MIoT' : 3000000000,
             'mMTC' : 3000000000,
             'voice' : 2000000000
           }

for n in range(simulation_time):
    
    # manage number active clients
    active = []
    new_connection = r.randint(0, len(clients_inRange))
    active = r.sample(clients_inRange, new_connection)
    
    for j in range(len(active)):
        if request_list[active[j].ID] == None:
            active_clients.append(active[j])

    print('STEP', n)
    
    for i in range(len(active_clients)):   
        # step 1 and create request
        active_clients[i].step_1()
        
        req = Request(active_clients[i].ID, active_clients[i].slice_type, active_clients[i].usage_rem, active_clients[i].usage_rem)
        request_list[active_clients[i].ID] = req
  
    for i in range(len(active_clients)):
        # step 2 and update request (delete non active user, and update traffic)
        active_clients[i].step_2()
        request_list[active_clients[i].ID].traffic_left = active_clients[i].usage_rem
    
    user_embb, user_urllc, user_miot, user_mmtc, user_voice = 0, 0, 0, 0, 0
    req_embb, req_urllc, req_miot, req_mmtc, req_voice = 0, 0, 0, 0, 0
    giv_embb, giv_urllc, giv_miot, giv_mmtc, giv_voice = 0, 0, 0, 0, 0
    for item in request_list:
     if item is not None:
        if item.type_slice == 'eMBB':
            if item.traffic_request - item.traffic_left != 0:
                req_embb += item.traffic_request
                giv_embb += item.traffic_request - item.traffic_left 
                user_embb += 1
            else:
                req_embb += 0
                giv_embb += 0
                
        if item.type_slice == 'URLLC' :
            if item.traffic_request - item.traffic_left != 0:
                req_urllc += item.traffic_request
                giv_urllc += item.traffic_request - item.traffic_left
                user_urllc += 1
            else:
                req_urllc += 0
                giv_urllc += 0
 
        if item.type_slice == 'MIoT':
            if item.traffic_request - item.traffic_left != 0:
                req_miot += item.traffic_request
                giv_miot += item.traffic_request - item.traffic_left
                user_miot += 1
            else:
                req_miot += 0
                giv_miot += 0
 
        if item.type_slice == 'mMTC':
            if item.traffic_request - item.traffic_left != 0:
                req_mmtc += item.traffic_request
                giv_mmtc += item.traffic_request - item.traffic_left
                user_mmtc += 1
            else:
                req_mmtc += 0
                giv_mmtc += 0

        if item.type_slice == 'voice':
            if item.traffic_request - item.traffic_left != 0:
                req_voice += item.traffic_request
                giv_voice += item.traffic_request - item.traffic_left
                user_voice += 1
            else:
                req_voice += 0
                giv_voice += 0
    
    csv_data = CsvData(n, req_embb, giv_embb, user_embb, req_urllc, giv_urllc, user_urllc, req_miot, giv_miot, user_miot, req_mmtc, giv_mmtc, user_mmtc, req_voice, giv_voice, user_voice)  
    csv_final.append(csv_data)
    # preditc ratios
    new_ratios = [[[req_embb, req_urllc, req_miot, req_mmtc, req_voice]]]
    new_ratios = np.array(new_ratios)/bs.capacity
    prediction = model.predict(new_ratios)
    capacity = get_new_ratios(prediction[0])
    
    for i in range(len(active_clients)):
        if active_clients[i].connected == False:
            request_list[active_clients[i].ID] = None

    for item in active_clients:
        # step 3 and delete also user not in range
        item.step_3()
        if item.connected == False:
            request_list[item.ID] = None
            active_clients.remove(item)
# Out:
# STEP 0
# Client 920, coordinates : (429, 521) connected to slice mMTC @ BS0
# Client_920, coordinates : (429, 521) requests 4498048 usage to BS0 to slice mMTC
# Client 883, coordinates : (292, 449) connected to slice MIoT @ BS0
# Client_883, coordinates : (292, 449) requests 6389834 usage to BS0 to slice MIoT
# Client 634, coordinates : (69, 478) connected to slice MIoT @ BS0
# Client_634, coordinates : (69, 478) requests 5300794 usage to BS0 to slice MIoT
# Client 345, coordinates : (449, 372) connected to slice eMBB @ BS0
# Client_345, coordinates : (449, 372) requests 409691043 usage to BS0 to slice eMBB
# Client 951, coordinates : (439, 145) connected to slice URLLC @ BS0
# Client_951, coordinates : (439, 145) requests 7137813 usage to BS0 to slice URLLC
# Client 618, coordinates : (400, 409) connected to slice MIoT @ BS0
# Client_618, coordinates : (400, 409) requests 4267205 usage to BS0 to slice MIoT
# Client 373, coordinates : (342, 179) connected to slice voice @ BS0
# Client_373, coordinates : (342, 179) requests 7098852 usage to BS0 to slice voice
# Client 167, coordinates : (300, 517) connected to slice voice @ BS0
# Client_167, coordinates : (300, 517) requests 4245573 usage to BS0 to slice voice
# Client 544, coordinates : (393, 254) connected to slice voice @ BS0
# Client_544, coordinates : (393, 254) requests 6222488 usage to BS0 to slice voice
# Client 398, coordinates : (262, 274) connected to slice voice @ BS0
# Client_398, coordinates : (262, 274) requests 7244712 usage to BS0 to slice voice
# Client 778, coordinates : (326, 60) connected to slice mMTC @ BS0
# Client_778, coordinates : (326, 60) requests 4630831 usage to BS0 to slice mMTC
# Client 423, coordinates : (312, 471) connected to slice voice @ BS0
# Client_423, coordinates : (312, 471) requests 7529695 usage to BS0 to slice voice
# Client 747, coordinates : (128, 218) connected to slice URLLC @ BS0
# Client_747, coordinates : (128, 218) requests 7350325 usage to BS0 to slice URLLC
# Client 246, coordinates : (533, 174) connected to slice URLLC @ BS0
# Client_246, coordinates : (533, 174) requests 7284345 usage to BS0 to slice URLLC
# Client 493, coordinates : (172, 200) connected to slice mMTC @ BS0
# Client_493, coordinates : (172, 200) requests 4670916 usage to BS0 to slice mMTC
# Client 556, coordinates : (300, 394) connected to slice voice @ BS0
# Client_556, coordinates : (300, 394) requests 6945474 usage to BS0 to slice voice
# Client 834, coordinates : (470, 351) connected to slice voice @ BS0
# Client_834, coordinates : (470, 351) requests 5613739 usage to BS0 to slice voice
# Client 845, coordinates : (121, 89) connected to slice mMTC @ BS0
# Client_845, coordinates : (121, 89) requests 6326663 usage to BS0 to slice mMTC
# Client 521, coordinates : (303, 247) connected to slice mMTC @ BS0
# Client_521, coordinates : (303, 247) requests 1825294 usage to BS0 to slice mMTC
# Client 261, coordinates : (166, 459) connected to slice eMBB @ BS0
# Client_261, coordinates : (166, 459) requests 303492615 usage to BS0 to slice eMBB
# Client 208, coordinates : (69, 525) connected to slice URLLC @ BS0
# Client_208, coordinates : (69, 525) requests 5991178 usage to BS0 to slice URLLC
# Client 537, coordinates : (228, 225) connected to slice mMTC @ BS0
# Client_537, coordinates : (228, 225) requests 7359785 usage to BS0 to slice mMTC
# Client 445, coordinates : (544, 350) connected to slice voice @ BS0
# Client_445, coordinates : (544, 350) requests 5423392 usage to BS0 to slice voice
# Client 605, coordinates : (209, 203) connected to slice eMBB @ BS0
# Client_605, coordinates : (209, 203) requests 98556074 usage to BS0 to slice eMBB
# Client 885, coordinates : (199, 513) connected to slice eMBB @ BS0
# Client_885, coordinates : (199, 513) requests 247139200 usage to BS0 to slice eMBB
# Client 629, coordinates : (235, 500) connected to slice eMBB @ BS0
# Client_629, coordinates : (235, 500) requests 168469499 usage to BS0 to slice eMBB
# Client 898, coordinates : (302, 408) connected to slice MIoT @ BS0
# Client_898, coordinates : (302, 408) requests 7917537 usage to BS0 to slice MIoT
# Client 20, coordinates : (289, 227) connected to slice URLLC @ BS0
# Client_20, coordinates : (289, 227) requests 6912977 usage to BS0 to slice URLLC
# Client 921, coordinates : (303, 421) connected to slice MIoT @ BS0
# Client_921, coordinates : (303, 421) requests 6312816 usage to BS0 to slice MIoT
# Client 809, coordinates : (307, 482) connected to slice URLLC @ BS0
# Client_809, coordinates : (307, 482) requests 6552200 usage to BS0 to slice URLLC
# Client 644, coordinates : (497, 281) connected to slice eMBB @ BS0
# Client_644, coordinates : (497, 281) requests 326883182 usage to BS0 to slice eMBB
# Client 151, coordinates : (276, 218) connected to slice mMTC @ BS0
# Client_151, coordinates : (276, 218) requests 7442765 usage to BS0 to slice mMTC
# Client 5, coordinates : (519, 89) connected to slice mMTC @ BS0
# Client_5, coordinates : (519, 89) requests 3154365 usage to BS0 to slice mMTC
# Client 760, coordinates : (53, 355) connected to slice eMBB @ BS0
# Client_760, coordinates : (53, 355) requests 193609727 usage to BS0 to slice eMBB
# Client 818, coordinates : (127, 527) connected to slice URLLC @ BS0
# Client_818, coordinates : (127, 527) requests 5735494 usage to BS0 to slice URLLC
# Client 835, coordinates : (282, 279) connected to slice eMBB @ BS0
# Client_835, coordinates : (282, 279) requests 187982352 usage to BS0 to slice eMBB
# Client 796, coordinates : (381, 365) connected to slice eMBB @ BS0
# Client_796, coordinates : (381, 365) requests 202594528 usage to BS0 to slice eMBB
# Client 274, coordinates : (225, 262) connected to slice URLLC @ BS0
# Client_274, coordinates : (225, 262) requests 5840297 usage to BS0 to slice URLLC
# Client 524, coordinates : (422, 439) connected to slice MIoT @ BS0
# Client_524, coordinates : (422, 439) requests 7400870 usage to BS0 to slice MIoT
# Client 604, coordinates : (125, 199) connection refused to slice URLLC @ BS0
# Client_604, coordinates : (125, 199) requests 7836530 usage to BS0 to slice URLLC
# Client 195, coordinates : (311, 439) connection refused to slice URLLC @ BS0
# Client_195, coordinates : (311, 439) requests 7324234 usage to BS0 to slice URLLC
# Client 965, coordinates : (362, 90) connected to slice eMBB @ BS0
# Client_965, coordinates : (362, 90) requests 499914422 usage to BS0 to slice eMBB
# Client 901, coordinates : (432, 94) connection refused to slice URLLC @ BS0
# Client_901, coordinates : (432, 94) requests 5295078 usage to BS0 to slice URLLC
# Client 540, coordinates : (210, 395) connected to slice eMBB @ BS0
# Client_540, coordinates : (210, 395) requests 289991853 usage to BS0 to slice eMBB
# Client 497, coordinates : (164, 445) connection refused to slice MIoT @ BS0
# Client_497, coordinates : (164, 445) requests 6106318 usage to BS0 to slice MIoT
# Client 925, coordinates : (189, 475) connection refused to slice URLLC @ BS0
# Client_925, coordinates : (189, 475) requests 6733395 usage to BS0 to slice URLLC
# Client 559, coordinates : (119, 306) connected to slice mMTC @ BS0
# Client_559, coordinates : (119, 306) requests 5587434 usage to BS0 to slice mMTC
# Client 687, coordinates : (336, 198) connection refused to slice URLLC @ BS0
# Client_687, coordinates : (336, 198) requests 5060706 usage to BS0 to slice URLLC
# Client 320, coordinates : (450, 519) connected to slice voice @ BS0
# Client_320, coordinates : (450, 519) requests 5602728 usage to BS0 to slice voice
# Client 41, coordinates : (385, 312) connected to slice mMTC @ BS0
# Client_41, coordinates : (385, 312) requests 7593422 usage to BS0 to slice mMTC
# Client 695, coordinates : (143, 62) connected to slice mMTC @ BS0
# Client_695, coordinates : (143, 62) requests 4465680 usage to BS0 to slice mMTC
# Client 227, coordinates : (301, 84) connected to slice voice @ BS0
# Client_227, coordinates : (301, 84) requests 6215981 usage to BS0 to slice voice
# Client 685, coordinates : (187, 500) connection refused to slice URLLC @ BS0
# Client_685, coordinates : (187, 500) requests 5473181 usage to BS0 to slice URLLC
# Client 176, coordinates : (135, 223) connection refused to slice URLLC @ BS0
# Client_176, coordinates : (135, 223) requests 6052064 usage to BS0 to slice URLLC
# Client 483, coordinates : (544, 189) connected to slice eMBB @ BS0
# Client_483, coordinates : (544, 189) requests 228700943 usage to BS0 to slice eMBB
# Client 87, coordinates : (89, 70) connected to slice eMBB @ BS0
# Client_87, coordinates : (89, 70) requests 66172186 usage to BS0 to slice eMBB
# Client 385, coordinates : (381, 154) connection refused to slice MIoT @ BS0
# Client_385, coordinates : (381, 154) requests 3644189 usage to BS0 to slice MIoT
# Client 88, coordinates : (53, 455) connection refused to slice URLLC @ BS0
# Client_88, coordinates : (53, 455) requests 5121133 usage to BS0 to slice URLLC
# Client 983, coordinates : (316, 407) connected to slice eMBB @ BS0
# Client_983, coordinates : (316, 407) requests 7370843 usage to BS0 to slice eMBB
# Client 764, coordinates : (73, 180) connection refused to slice URLLC @ BS0
# Client_764, coordinates : (73, 180) requests 6856330 usage to BS0 to slice URLLC
# Client 688, coordinates : (319, 191) connection refused to slice MIoT @ BS0
# Client_688, coordinates : (319, 191) requests 7291085 usage to BS0 to slice MIoT
# Client 494, coordinates : (354, 133) connected to slice mMTC @ BS0
# Client_494, coordinates : (354, 133) requests 4940251 usage to BS0 to slice mMTC
# Client 846, coordinates : (479, 216) connected to slice mMTC @ BS0
# Client_846, coordinates : (479, 216) requests 7968028 usage to BS0 to slice mMTC
# Client 996, coordinates : (194, 73) connected to slice eMBB @ BS0
# Client_996, coordinates : (194, 73) requests 358619051 usage to BS0 to slice eMBB
# Client 126, coordinates : (488, 93) connection refused to slice MIoT @ BS0
# Client_126, coordinates : (488, 93) requests 7468320 usage to BS0 to slice MIoT
# Client 954, coordinates : (174, 194) connection refused to slice URLLC @ BS0
# Client_954, coordinates : (174, 194) requests 5473171 usage to BS0 to slice URLLC
# Client 731, coordinates : (95, 430) connected to slice mMTC @ BS0
# Client_731, coordinates : (95, 430) requests 1410676 usage to BS0 to slice mMTC
# Client 24, coordinates : (146, 346) connection refused to slice URLLC @ BS0
# Client_24, coordinates : (146, 346) requests 6773279 usage to BS0 to slice URLLC
# Client 589, coordinates : (380, 121) connected to slice voice @ BS0
# Client_589, coordinates : (380, 121) requests 5829159 usage to BS0 to slice voice
# Client 459, coordinates : (264, 399) connected to slice voice @ BS0
# Client_459, coordinates : (264, 399) requests 5745649 usage to BS0 to slice voice
# Client 175, coordinates : (231, 288) connected to slice voice @ BS0
# Client_175, coordinates : (231, 288) requests 4585235 usage to BS0 to slice voice
# Client 735, coordinates : (434, 521) connection refused to slice URLLC @ BS0
# Client_735, coordinates : (434, 521) requests 6879036 usage to BS0 to slice URLLC
# Client 90, coordinates : (223, 86) connection refused to slice URLLC @ BS0
# Client_90, coordinates : (223, 86) requests 6004866 usage to BS0 to slice URLLC
# Client 415, coordinates : (305, 524) connected to slice eMBB @ BS0
# Client_415, coordinates : (305, 524) requests 451202524 usage to BS0 to slice eMBB
# Client 897, coordinates : (178, 448) connection refused to slice URLLC @ BS0
# Client_897, coordinates : (178, 448) requests 7743952 usage to BS0 to slice URLLC
# Client 726, coordinates : (377, 51) connection refused to slice MIoT @ BS0
# Client_726, coordinates : (377, 51) requests 1215677 usage to BS0 to slice MIoT
# Client 192, coordinates : (191, 199) connected to slice voice @ BS0
# Client_192, coordinates : (191, 199) requests 5220476 usage to BS0 to slice voice
# Client 823, coordinates : (304, 337) connection refused to slice URLLC @ BS0
# Client_823, coordinates : (304, 337) requests 7377868 usage to BS0 to slice URLLC
# Client 978, coordinates : (80, 532) connected to slice eMBB @ BS0
# Client_978, coordinates : (80, 532) requests 463348103 usage to BS0 to slice eMBB
# Client 635, coordinates : (191, 92) connection refused to slice MIoT @ BS0
# Client_635, coordinates : (191, 92) requests 7077044 usage to BS0 to slice MIoT
# Client 734, coordinates : (84, 165) connected to slice mMTC @ BS0
# Client_734, coordinates : (84, 165) requests 1922916 usage to BS0 to slice mMTC
# Client 444, coordinates : (196, 379) connected to slice eMBB @ BS0
# Client_444, coordinates : (196, 379) requests 153483181 usage to BS0 to slice eMBB
# Client 404, coordinates : (234, 452) connection refused to slice URLLC @ BS0
# Client_404, coordinates : (234, 452) requests 7297468 usage to BS0 to slice URLLC
# Client 903, coordinates : (279, 84) connection refused to slice URLLC @ BS0
# Client_903, coordinates : (279, 84) requests 6988445 usage to BS0 to slice URLLC
# Client 153, coordinates : (178, 228) connection refused to slice MIoT @ BS0
# Client_153, coordinates : (178, 228) requests 3490565 usage to BS0 to slice MIoT
# Client 531, coordinates : (132, 509) connection refused to slice URLLC @ BS0
# Client_531, coordinates : (132, 509) requests 7877718 usage to BS0 to slice URLLC
# Client 204, coordinates : (248, 118) connected to slice eMBB @ BS0
# Client_204, coordinates : (248, 118) requests 484070064 usage to BS0 to slice eMBB
# Client 913, coordinates : (485, 530) connected to slice voice @ BS0
# Client_913, coordinates : (485, 530) requests 6618226 usage to BS0 to slice voice
# Client 950, coordinates : (352, 160) connected to slice voice @ BS0
# Client_950, coordinates : (352, 160) requests 4661038 usage to BS0 to slice voice
# Client 490, coordinates : (355, 117) connected to slice mMTC @ BS0
# Client_490, coordinates : (355, 117) requests 7687862 usage to BS0 to slice mMTC
# Client 430, coordinates : (86, 157) connected to slice eMBB @ BS0
# Client_430, coordinates : (86, 157) requests 25922495 usage to BS0 to slice eMBB
# Client 696, coordinates : (117, 370) connected to slice mMTC @ BS0
# Client_696, coordinates : (117, 370) requests 7076088 usage to BS0 to slice mMTC
# Client 819, coordinates : (477, 373) connected to slice voice @ BS0
# Client_819, coordinates : (477, 373) requests 7633826 usage to BS0 to slice voice
# Client 933, coordinates : (68, 202) connected to slice eMBB @ BS0
# Client_933, coordinates : (68, 202) requests 26847036 usage to BS0 to slice eMBB
# Client 427, coordinates : (162, 496) connected to slice mMTC @ BS0
# Client_427, coordinates : (162, 496) requests 3583063 usage to BS0 to slice mMTC
# Client 206, coordinates : (182, 272) connected to slice voice @ BS0
# Client_206, coordinates : (182, 272) requests 4790076 usage to BS0 to slice voice
# Client 34, coordinates : (335, 503) connection refused to slice URLLC @ BS0
# Client_34, coordinates : (335, 503) requests 5141437 usage to BS0 to slice URLLC
# Client 562, coordinates : (240, 482) connected to slice eMBB @ BS0
# Client_562, coordinates : (240, 482) requests 347915951 usage to BS0 to slice eMBB
# Client 482, coordinates : (194, 278) connection refused to slice URLLC @ BS0
# Client_482, coordinates : (194, 278) requests 7887785 usage to BS0 to slice URLLC
# Client 389, coordinates : (135, 507) connected to slice voice @ BS0
# Client_389, coordinates : (135, 507) requests 6792887 usage to BS0 to slice voice
# Client 29, coordinates : (502, 407) connection refused to slice URLLC @ BS0
# Client_29, coordinates : (502, 407) requests 5324034 usage to BS0 to slice URLLC
# Client 54, coordinates : (117, 405) connected to slice eMBB @ BS0
# Client_54, coordinates : (117, 405) requests 12753853 usage to BS0 to slice eMBB
# Client 479, coordinates : (116, 379) connection refused to slice URLLC @ BS0
# Client_479, coordinates : (116, 379) requests 7439302 usage to BS0 to slice URLLC
# Client 715, coordinates : (387, 409) connected to slice eMBB @ BS0
# Client_715, coordinates : (387, 409) requests 53999069 usage to BS0 to slice eMBB
# Client 519, coordinates : (217, 161) connected to slice eMBB @ BS0
# Client_519, coordinates : (217, 161) requests 353861443 usage to BS0 to slice eMBB
# Client 302, coordinates : (85, 516) connected to slice voice @ BS0
# Client_302, coordinates : (85, 516) requests 5360509 usage to BS0 to slice voice
# Client 953, coordinates : (507, 197) connection refused to slice voice @ BS0
# Client_953, coordinates : (507, 197) requests 5677508 usage to BS0 to slice voice
# Client 728, coordinates : (546, 474) connection refused to slice voice @ BS0
# Client_728, coordinates : (546, 474) requests 7920938 usage to BS0 to slice voice
# Client 690, coordinates : (261, 360) connection refused to slice voice @ BS0
# Client_690, coordinates : (261, 360) requests 4365507 usage to BS0 to slice voice
# Client 988, coordinates : (174, 262) connection refused to slice MIoT @ BS0
# Client_988, coordinates : (174, 262) requests 1929953 usage to BS0 to slice MIoT
# Client 165, coordinates : (190, 69) connected to slice eMBB @ BS0
# Client_165, coordinates : (190, 69) requests 46164611 usage to BS0 to slice eMBB
# Client 357, coordinates : (234, 61) connection refused to slice voice @ BS0
# Client_357, coordinates : (234, 61) requests 5679576 usage to BS0 to slice voice
# Client 670, coordinates : (88, 317) connected to slice eMBB @ BS0
# Client_670, coordinates : (88, 317) requests 6340722 usage to BS0 to slice eMBB
# Client 299, coordinates : (357, 545) connection refused to slice MIoT @ BS0
# Client_299, coordinates : (357, 545) requests 2294217 usage to BS0 to slice MIoT
# Client 84, coordinates : (471, 520) connected to slice eMBB @ BS0
# Client_84, coordinates : (471, 520) requests 227709774 usage to BS0 to slice eMBB
# Client 995, coordinates : (188, 282) connected to slice mMTC @ BS0
# Client_995, coordinates : (188, 282) requests 4492745 usage to BS0 to slice mMTC
# Client 608, coordinates : (525, 420) connected to slice eMBB @ BS0
# Client_608, coordinates : (525, 420) requests 82344832 usage to BS0 to slice eMBB
# Client 914, coordinates : (477, 410) connection refused to slice voice @ BS0
# Client_914, coordinates : (477, 410) requests 5421710 usage to BS0 to slice voice
# Client 802, coordinates : (412, 513) connected to slice mMTC @ BS0
# Client_802, coordinates : (412, 513) requests 2975881 usage to BS0 to slice mMTC
# Client 201, coordinates : (525, 400) connection refused to slice MIoT @ BS0
# Client_201, coordinates : (525, 400) requests 5770433 usage to BS0 to slice MIoT
# Client 893, coordinates : (202, 210) connection refused to slice voice @ BS0
# Client_893, coordinates : (202, 210) requests 6996760 usage to BS0 to slice voice
# Client 243, coordinates : (136, 238) connection refused to slice MIoT @ BS0
# Client_243, coordinates : (136, 238) requests 7044225 usage to BS0 to slice MIoT
# Client 191, coordinates : (220, 292) connection refused to slice MIoT @ BS0
# Client_191, coordinates : (220, 292) requests 2093043 usage to BS0 to slice MIoT
# Client 169, coordinates : (485, 442) connected to slice eMBB @ BS0
# Client_169, coordinates : (485, 442) requests 339199454 usage to BS0 to slice eMBB
# Client 730, coordinates : (81, 187) connection refused to slice URLLC @ BS0
# Client_730, coordinates : (81, 187) requests 6382466 usage to BS0 to slice URLLC
# Client 617, coordinates : (56, 102) connected to slice eMBB @ BS0
# Client_617, coordinates : (56, 102) requests 373822917 usage to BS0 to slice eMBB
# Client 382, coordinates : (247, 488) connected to slice mMTC @ BS0
# Client_382, coordinates : (247, 488) requests 5054928 usage to BS0 to slice mMTC
# Client 630, coordinates : (74, 273) connected to slice mMTC @ BS0
# Client_630, coordinates : (74, 273) requests 4568011 usage to BS0 to slice mMTC
# Client 705, coordinates : (338, 56) connected to slice mMTC @ BS0
# Client_705, coordinates : (338, 56) requests 3952556 usage to BS0 to slice mMTC
# Client 584, coordinates : (398, 261) connection refused to slice voice @ BS0
# Client_584, coordinates : (398, 261) requests 6648102 usage to BS0 to slice voice
# Client 674, coordinates : (545, 290) connection refused to slice URLLC @ BS0
# Client_674, coordinates : (545, 290) requests 6117994 usage to BS0 to slice URLLC
# Client 79, coordinates : (372, 377) connection refused to slice URLLC @ BS0
# Client_79, coordinates : (372, 377) requests 7911164 usage to BS0 to slice URLLC
# Client 200, coordinates : (141, 508) connected to slice mMTC @ BS0
# Client_200, coordinates : (141, 508) requests 7207389 usage to BS0 to slice mMTC
# Client 654, coordinates : (164, 444) connected to slice mMTC @ BS0
# Client_654, coordinates : (164, 444) requests 4879013 usage to BS0 to slice mMTC
# Client 621, coordinates : (285, 301) connection refused to slice voice @ BS0
# Client_621, coordinates : (285, 301) requests 7248982 usage to BS0 to slice voice
# Client 698, coordinates : (340, 239) connection refused to slice URLLC @ BS0
# Client_698, coordinates : (340, 239) requests 5384183 usage to BS0 to slice URLLC
# Client 108, coordinates : (72, 501) connection refused to slice URLLC @ BS0
# Client_108, coordinates : (72, 501) requests 6986744 usage to BS0 to slice URLLC
# Client 17, coordinates : (145, 172) connected to slice mMTC @ BS0
# Client_17, coordinates : (145, 172) requests 3616480 usage to BS0 to slice mMTC
# Client 810, coordinates : (140, 318) connection refused to slice voice @ BS0
# Client_810, coordinates : (140, 318) requests 4421911 usage to BS0 to slice voice
# Client 409, coordinates : (477, 323) connected to slice mMTC @ BS0
# Client_409, coordinates : (477, 323) requests 2523793 usage to BS0 to slice mMTC
# Client 150, coordinates : (346, 170) connection refused to slice URLLC @ BS0
# Client_150, coordinates : (346, 170) requests 7778508 usage to BS0 to slice URLLC
# Client 765, coordinates : (155, 223) connected to slice eMBB @ BS0
# Client_765, coordinates : (155, 223) requests 346551570 usage to BS0 to slice eMBB
# Client 777, coordinates : (436, 516) connection refused to slice voice @ BS0
# Client_777, coordinates : (436, 516) requests 5698923 usage to BS0 to slice voice
# Client 716, coordinates : (341, 76) connected to slice mMTC @ BS0
# Client_716, coordinates : (341, 76) requests 4780028 usage to BS0 to slice mMTC
# Client 866, coordinates : (497, 528) connection refused to slice voice @ BS0
# Client_866, coordinates : (497, 528) requests 7929351 usage to BS0 to slice voice
# Client 110, coordinates : (332, 51) connected to slice eMBB @ BS0
# Client_110, coordinates : (332, 51) requests 158831485 usage to BS0 to slice eMBB
# Client 355, coordinates : (503, 516) connection refused to slice voice @ BS0
# Client_355, coordinates : (503, 516) requests 5340915 usage to BS0 to slice voice
# Client 868, coordinates : (237, 305) connection refused to slice URLLC @ BS0
# Client_868, coordinates : (237, 305) requests 5829578 usage to BS0 to slice URLLC
# Client 939, coordinates : (392, 435) connected to slice mMTC @ BS0
# Client_939, coordinates : (392, 435) requests 7904462 usage to BS0 to slice mMTC
# Client 571, coordinates : (219, 428) connected to slice eMBB @ BS0
# Client_571, coordinates : (219, 428) requests 338088068 usage to BS0 to slice eMBB
# Client 117, coordinates : (70, 355) connection refused to slice voice @ BS0
# Client_117, coordinates : (70, 355) requests 4740675 usage to BS0 to slice voice
# Client 45, coordinates : (373, 519) connection refused to slice URLLC @ BS0
# Client_45, coordinates : (373, 519) requests 5906731 usage to BS0 to slice URLLC
# Client 397, coordinates : (537, 287) connection refused to slice voice @ BS0
# Client_397, coordinates : (537, 287) requests 6671582 usage to BS0 to slice voice
# Client 122, coordinates : (363, 266) connection refused to slice MIoT @ BS0
# Client_122, coordinates : (363, 266) requests 2116052 usage to BS0 to slice MIoT
# Client 173, coordinates : (351, 215) connection refused to slice MIoT @ BS0
# Client_173, coordinates : (351, 215) requests 4357301 usage to BS0 to slice MIoT
# Client 684, coordinates : (368, 133) connection refused to slice voice @ BS0
# Client_684, coordinates : (368, 133) requests 6397240 usage to BS0 to slice voice
# Client 566, coordinates : (199, 477) connection refused to slice MIoT @ BS0
# Client_566, coordinates : (199, 477) requests 6573592 usage to BS0 to slice MIoT
# Client 610, coordinates : (421, 455) connection refused to slice URLLC @ BS0
# Client_610, coordinates : (421, 455) requests 7425904 usage to BS0 to slice URLLC
# Client 642, coordinates : (145, 108) connection refused to slice URLLC @ BS0
# Client_642, coordinates : (145, 108) requests 7117299 usage to BS0 to slice URLLC
# Client 790, coordinates : (83, 208) connection refused to slice URLLC @ BS0
# Client_790, coordinates : (83, 208) requests 6756611 usage to BS0 to slice URLLC
# Client 290, coordinates : (536, 287) connection refused to slice voice @ BS0
# Client_290, coordinates : (536, 287) requests 6648692 usage to BS0 to slice voice
# Client 552, coordinates : (409, 548) connection refused to slice voice @ BS0
# Client_552, coordinates : (409, 548) requests 6509013 usage to BS0 to slice voice
# Client 551, coordinates : (460, 369) connection refused to slice URLLC @ BS0
# Client_551, coordinates : (460, 369) requests 7398005 usage to BS0 to slice URLLC
# Client 275, coordinates : (253, 446) connected to slice eMBB @ BS0
# Client_275, coordinates : (253, 446) requests 218937741 usage to BS0 to slice eMBB
# Client 994, coordinates : (115, 126) connection refused to slice URLLC @ BS0
# Client_994, coordinates : (115, 126) requests 6475001 usage to BS0 to slice URLLC
# Client 660, coordinates : (304, 336) connected to slice mMTC @ BS0
# Client_660, coordinates : (304, 336) requests 5951282 usage to BS0 to slice mMTC
# Client 587, coordinates : (224, 450) connected to slice eMBB @ BS0
# Client_587, coordinates : (224, 450) requests 402831938 usage to BS0 to slice eMBB
# Client 15, coordinates : (308, 243) connection refused to slice URLLC @ BS0
# Client_15, coordinates : (308, 243) requests 5925955 usage to BS0 to slice URLLC
# Client 750, coordinates : (357, 433) connection refused to slice voice @ BS0
# Client_750, coordinates : (357, 433) requests 7437142 usage to BS0 to slice voice
# Client 843, coordinates : (245, 226) connection refused to slice voice @ BS0
# Client_843, coordinates : (245, 226) requests 4706200 usage to BS0 to slice voice
# Client 465, coordinates : (424, 490) connected to slice eMBB @ BS0
# Client_465, coordinates : (424, 490) requests 486842482 usage to BS0 to slice eMBB
# Client 188, coordinates : (425, 494) connection refused to slice URLLC @ BS0
# Client_188, coordinates : (425, 494) requests 5332371 usage to BS0 to slice URLLC
# Client 431, coordinates : (372, 512) connected to slice eMBB @ BS0
# Client_431, coordinates : (372, 512) requests 72015204 usage to BS0 to slice eMBB
# Client 284, coordinates : (187, 109) connected to slice mMTC @ BS0
# Client_284, coordinates : (187, 109) requests 6370939 usage to BS0 to slice mMTC
# Client 922, coordinates : (140, 362) connection refused to slice MIoT @ BS0
# Client_922, coordinates : (140, 362) requests 4258747 usage to BS0 to slice MIoT
# Client 375, coordinates : (375, 219) connection refused to slice URLLC @ BS0
# Client_375, coordinates : (375, 219) requests 7959210 usage to BS0 to slice URLLC
# Client 498, coordinates : (179, 439) connection refused to slice URLLC @ BS0
# Client_498, coordinates : (179, 439) requests 7082875 usage to BS0 to slice URLLC
# Client 992, coordinates : (59, 52) connection refused to slice voice @ BS0
# Client_992, coordinates : (59, 52) requests 4253250 usage to BS0 to slice voice
# Client 288, coordinates : (474, 371) connection refused to slice URLLC @ BS0
# Client_288, coordinates : (474, 371) requests 6649708 usage to BS0 to slice URLLC
# Client 454, coordinates : (365, 217) connected to slice eMBB @ BS0
# Client_454, coordinates : (365, 217) requests 340874912 usage to BS0 to slice eMBB
# Client 596, coordinates : (146, 164) connection refused to slice URLLC @ BS0
# Client_596, coordinates : (146, 164) requests 5709378 usage to BS0 to slice URLLC
# Client 401, coordinates : (385, 58) connection refused to slice URLLC @ BS0
# Client_401, coordinates : (385, 58) requests 7440845 usage to BS0 to slice URLLC
# Client 95, coordinates : (272, 229) connection refused to slice MIoT @ BS0
# Client_95, coordinates : (272, 229) requests 4592420 usage to BS0 to slice MIoT
# Client 331, coordinates : (130, 437) connected to slice mMTC @ BS0
# Client_331, coordinates : (130, 437) requests 7564162 usage to BS0 to slice mMTC
# Client 779, coordinates : (443, 441) connection refused to slice MIoT @ BS0
# Client_779, coordinates : (443, 441) requests 6629552 usage to BS0 to slice MIoT
# Client 985, coordinates : (496, 369) connection refused to slice URLLC @ BS0
# Client_985, coordinates : (496, 369) requests 5231594 usage to BS0 to slice URLLC
# Client 937, coordinates : (391, 61) connected to slice mMTC @ BS0
# Client_937, coordinates : (391, 61) requests 6754031 usage to BS0 to slice mMTC
# Client 505, coordinates : (287, 460) connection refused to slice URLLC @ BS0
# Client_505, coordinates : (287, 460) requests 5357588 usage to BS0 to slice URLLC
# Client 27, coordinates : (220, 236) connection refused to slice voice @ BS0
# Client_27, coordinates : (220, 236) requests 7707177 usage to BS0 to slice voice
# Client 220, coordinates : (517, 312) connected to slice eMBB @ BS0
# Client_220, coordinates : (517, 312) requests 266312142 usage to BS0 to slice eMBB
# Client 854, coordinates : (262, 76) connection refused to slice voice @ BS0
# Client_854, coordinates : (262, 76) requests 5761769 usage to BS0 to slice voice
# Client 816, coordinates : (334, 279) connection refused to slice voice @ BS0
# Client_816, coordinates : (334, 279) requests 6129777 usage to BS0 to slice voice
# Client 852, coordinates : (254, 74) connected to slice eMBB @ BS0
# Client_852, coordinates : (254, 74) requests 333739566 usage to BS0 to slice eMBB
# Client 369, coordinates : (149, 475) connected to slice eMBB @ BS0
# Client_369, coordinates : (149, 475) requests 202079166 usage to BS0 to slice eMBB
# Client 944, coordinates : (125, 539) connected to slice eMBB @ BS0
# Client_944, coordinates : (125, 539) requests 412336448 usage to BS0 to slice eMBB
# Client 666, coordinates : (233, 446) connection refused to slice voice @ BS0
# Client_666, coordinates : (233, 446) requests 6470532 usage to BS0 to slice voice
# Client 805, coordinates : (506, 357) connected to slice eMBB @ BS0
# Client_805, coordinates : (506, 357) requests 158599737 usage to BS0 to slice eMBB
# Client 838, coordinates : (253, 528) connection refused to slice MIoT @ BS0
# Client_838, coordinates : (253, 528) requests 2331992 usage to BS0 to slice MIoT
# Client 46, coordinates : (69, 437) connection refused to slice URLLC @ BS0
# Client_46, coordinates : (69, 437) requests 5106264 usage to BS0 to slice URLLC
# Client 763, coordinates : (502, 293) connected to slice mMTC @ BS0
# Client_763, coordinates : (502, 293) requests 7755064 usage to BS0 to slice mMTC
# Client 899, coordinates : (123, 142) connected to slice eMBB @ BS0
# Client_899, coordinates : (123, 142) requests 56254613 usage to BS0 to slice eMBB
# Client 704, coordinates : (281, 273) connection refused to slice MIoT @ BS0
# Client_704, coordinates : (281, 273) requests 4973192 usage to BS0 to slice MIoT
# Client 828, coordinates : (498, 93) connection refused to slice voice @ BS0
# Client_828, coordinates : (498, 93) requests 6923629 usage to BS0 to slice voice
# Client 130, coordinates : (394, 164) connected to slice eMBB @ BS0
# Client_130, coordinates : (394, 164) requests 210765056 usage to BS0 to slice eMBB
# Client 591, coordinates : (143, 66) connection refused to slice URLLC @ BS0
# Client_591, coordinates : (143, 66) requests 7631029 usage to BS0 to slice URLLC
# Client 633, coordinates : (82, 193) connected to slice eMBB @ BS0
# Client_633, coordinates : (82, 193) requests 203869657 usage to BS0 to slice eMBB
# Client 155, coordinates : (338, 318) connected to slice eMBB @ BS0
# Client_155, coordinates : (338, 318) requests 376186537 usage to BS0 to slice eMBB
# Client 341, coordinates : (508, 61) connection refused to slice URLLC @ BS0
# Client_341, coordinates : (508, 61) requests 7700645 usage to BS0 to slice URLLC
# Client 232, coordinates : (369, 465) connected to slice mMTC @ BS0
# Client_232, coordinates : (369, 465) requests 2647919 usage to BS0 to slice mMTC
# Client 296, coordinates : (513, 218) connection refused to slice MIoT @ BS0
# Client_296, coordinates : (513, 218) requests 3975675 usage to BS0 to slice MIoT
# Client 929, coordinates : (228, 525) connection refused to slice MIoT @ BS0
# Client_929, coordinates : (228, 525) requests 1830894 usage to BS0 to slice MIoT
# Client 229, coordinates : (310, 477) connection refused to slice voice @ BS0
# Client_229, coordinates : (310, 477) requests 6518059 usage to BS0 to slice voice
# Client 742, coordinates : (341, 361) connected to slice eMBB @ BS0
# Client_742, coordinates : (341, 361) requests 384675847 usage to BS0 to slice eMBB
# Client 134, coordinates : (66, 116) connected to slice eMBB @ BS0
# Client_134, coordinates : (66, 116) requests 223288536 usage to BS0 to slice eMBB
# Client 174, coordinates : (396, 92) connected to slice eMBB @ BS0
# Client_174, coordinates : (396, 92) requests 321127440 usage to BS0 to slice eMBB
# Client 822, coordinates : (524, 530) connection refused to slice URLLC @ BS0
# Client_822, coordinates : (524, 530) requests 5838116 usage to BS0 to slice URLLC
# Client 533, coordinates : (455, 499) connected to slice mMTC @ BS0
# Client_533, coordinates : (455, 499) requests 1455245 usage to BS0 to slice mMTC
# Client 8, coordinates : (294, 543) connected to slice mMTC @ BS0
# Client_8, coordinates : (294, 543) requests 7252170 usage to BS0 to slice mMTC
# Client 774, coordinates : (112, 230) connected to slice mMTC @ BS0
# Client_774, coordinates : (112, 230) requests 3474475 usage to BS0 to slice mMTC
# Client 895, coordinates : (541, 85) connection refused to slice URLLC @ BS0
# Client_895, coordinates : (541, 85) requests 7115685 usage to BS0 to slice URLLC
# Client 875, coordinates : (333, 413) connection refused to slice voice @ BS0
# Client_875, coordinates : (333, 413) requests 6653960 usage to BS0 to slice voice
# Client 314, coordinates : (461, 524) connection refused to slice voice @ BS0
# Client_314, coordinates : (461, 524) requests 4431537 usage to BS0 to slice voice
# Client 743, coordinates : (533, 208) connection refused to slice voice @ BS0
# Client_743, coordinates : (533, 208) requests 4684559 usage to BS0 to slice voice
# Client 729, coordinates : (541, 301) connection refused to slice MIoT @ BS0
# Client_729, coordinates : (541, 301) requests 6874150 usage to BS0 to slice MIoT
# Client 324, coordinates : (472, 523) connection refused to slice voice @ BS0
# Client_324, coordinates : (472, 523) requests 4332297 usage to BS0 to slice voice
# Client 291, coordinates : (398, 87) connection refused to slice voice @ BS0
# Client_291, coordinates : (398, 87) requests 6711109 usage to BS0 to slice voice
# Client 156, coordinates : (196, 285) connected to slice eMBB @ BS0
# Client_156, coordinates : (196, 285) requests 425375675 usage to BS0 to slice eMBB
# Client 281, coordinates : (118, 534) connected to slice mMTC @ BS0
# Client_281, coordinates : (118, 534) requests 4799145 usage to BS0 to slice mMTC
# Client 865, coordinates : (544, 310) connected to slice eMBB @ BS0
# Client_865, coordinates : (544, 310) requests 160264318 usage to BS0 to slice eMBB
# Client 686, coordinates : (288, 297) connection refused to slice URLLC @ BS0
# Client_686, coordinates : (288, 297) requests 6991536 usage to BS0 to slice URLLC
# Client 91, coordinates : (335, 541) connected to slice eMBB @ BS0
# Client_91, coordinates : (335, 541) requests 383647458 usage to BS0 to slice eMBB
# Client 309, coordinates : (228, 209) connection refused to slice voice @ BS0
# Client_309, coordinates : (228, 209) requests 7865194 usage to BS0 to slice voice
# Client 522, coordinates : (340, 227) connection refused to slice MIoT @ BS0
# Client_522, coordinates : (340, 227) requests 3544915 usage to BS0 to slice MIoT
# Client 911, coordinates : (78, 493) connected to slice eMBB @ BS0
# Client_911, coordinates : (78, 493) requests 431952097 usage to BS0 to slice eMBB
# Client 429, coordinates : (345, 362) connection refused to slice MIoT @ BS0
# Client_429, coordinates : (345, 362) requests 4334901 usage to BS0 to slice MIoT
# Client 955, coordinates : (529, 506) connection refused to slice voice @ BS0
# Client_955, coordinates : (529, 506) requests 5622321 usage to BS0 to slice voice
# Client 879, coordinates : (284, 335) connection refused to slice voice @ BS0
# Client_879, coordinates : (284, 335) requests 5090895 usage to BS0 to slice voice
# Client 69, coordinates : (74, 399) connected to slice mMTC @ BS0
# Client_69, coordinates : (74, 399) requests 5703639 usage to BS0 to slice mMTC
# Client 414, coordinates : (200, 431) connection refused to slice URLLC @ BS0
# Client_414, coordinates : (200, 431) requests 5996041 usage to BS0 to slice URLLC
# Client 376, coordinates : (213, 100) connection refused to slice MIoT @ BS0
# Client_376, coordinates : (213, 100) requests 6626958 usage to BS0 to slice MIoT
# Client 81, coordinates : (122, 492) connection refused to slice URLLC @ BS0
# Client_81, coordinates : (122, 492) requests 6867520 usage to BS0 to slice URLLC
# Client 757, coordinates : (169, 211) connected to slice eMBB @ BS0
# Client_757, coordinates : (169, 211) requests 261044001 usage to BS0 to slice eMBB
# Client 224, coordinates : (152, 492) connection refused to slice MIoT @ BS0
# Client_224, coordinates : (152, 492) requests 5294627 usage to BS0 to slice MIoT
# Client 129, coordinates : (411, 207) connected to slice mMTC @ BS0
# Client_129, coordinates : (411, 207) requests 2298966 usage to BS0 to slice mMTC
# Client 532, coordinates : (359, 372) connection refused to slice URLLC @ BS0
# Client_532, coordinates : (359, 372) requests 5049637 usage to BS0 to slice URLLC
# Client 11, coordinates : (215, 541) connection refused to slice URLLC @ BS0
# Client_11, coordinates : (215, 541) requests 7435566 usage to BS0 to slice URLLC
# Client 557, coordinates : (75, 225) connection refused to slice URLLC @ BS0
# Client_557, coordinates : (75, 225) requests 7326572 usage to BS0 to slice URLLC
# Client 861, coordinates : (446, 160) connection refused to slice voice @ BS0
# Client_861, coordinates : (446, 160) requests 5557770 usage to BS0 to slice voice
# Client 488, coordinates : (528, 189) connection refused to slice URLLC @ BS0
# Client_488, coordinates : (528, 189) requests 7652624 usage to BS0 to slice URLLC
# Client 112, coordinates : (330, 456) connection refused to slice MIoT @ BS0
# Client_112, coordinates : (330, 456) requests 2590938 usage to BS0 to slice MIoT
# Client 820, coordinates : (423, 536) connection refused to slice URLLC @ BS0
# Client_820, coordinates : (423, 536) requests 7599613 usage to BS0 to slice URLLC
# Client 782, coordinates : (107, 171) connected to slice mMTC @ BS0
# Client_782, coordinates : (107, 171) requests 2010301 usage to BS0 to slice mMTC
# Client 798, coordinates : (212, 404) connected to slice eMBB @ BS0
# Client_798, coordinates : (212, 404) requests 209127791 usage to BS0 to slice eMBB
# Client 963, coordinates : (274, 273) connected to slice mMTC @ BS0
# Client_963, coordinates : (274, 273) requests 5999569 usage to BS0 to slice mMTC
# Client 484, coordinates : (90, 394) connection refused to slice voice @ BS0
# Client_484, coordinates : (90, 394) requests 5521440 usage to BS0 to slice voice
# Client 632, coordinates : (539, 146) connection refused to slice voice @ BS0
# Client_632, coordinates : (539, 146) requests 6773971 usage to BS0 to slice voice
# Client 952, coordinates : (216, 107) connected to slice eMBB @ BS0
# Client_952, coordinates : (216, 107) requests 149617018 usage to BS0 to slice eMBB
# Client 421, coordinates : (152, 126) connection refused to slice URLLC @ BS0
# Client_421, coordinates : (152, 126) requests 7990906 usage to BS0 to slice URLLC
# Client 286, coordinates : (277, 125) connection refused to slice voice @ BS0
# Client_286, coordinates : (277, 125) requests 4816301 usage to BS0 to slice voice
# Client 179, coordinates : (410, 119) connection refused to slice MIoT @ BS0
# Client_179, coordinates : (410, 119) requests 6420112 usage to BS0 to slice MIoT
# Client 13, coordinates : (166, 488) connected to slice eMBB @ BS0
# Client_13, coordinates : (166, 488) requests 156940674 usage to BS0 to slice eMBB
# Client 144, coordinates : (386, 188) connection refused to slice URLLC @ BS0
# Client_144, coordinates : (386, 188) requests 7558451 usage to BS0 to slice URLLC
# Client 107, coordinates : (194, 338) connected to slice mMTC @ BS0
# Client_107, coordinates : (194, 338) requests 5682147 usage to BS0 to slice mMTC
# Client 235, coordinates : (323, 127) connection refused to slice voice @ BS0
# Client_235, coordinates : (323, 127) requests 6293451 usage to BS0 to slice voice
# Client 772, coordinates : (218, 142) connected to slice eMBB @ BS0
# Client_772, coordinates : (218, 142) requests 205741611 usage to BS0 to slice eMBB
# Client 198, coordinates : (105, 325) connected to slice mMTC @ BS0
# Client_198, coordinates : (105, 325) requests 3500368 usage to BS0 to slice mMTC
# Client 998, coordinates : (353, 323) connection refused to slice voice @ BS0
# Client_998, coordinates : (353, 323) requests 5340802 usage to BS0 to slice voice
# Client 194, coordinates : (182, 388) connection refused to slice voice @ BS0
# Client_194, coordinates : (182, 388) requests 6423693 usage to BS0 to slice voice
# Client 51, coordinates : (91, 190) connection refused to slice URLLC @ BS0
# Client_51, coordinates : (91, 190) requests 7580409 usage to BS0 to slice URLLC
# Client 77, coordinates : (312, 65) connected to slice eMBB @ BS0
# Client_77, coordinates : (312, 65) requests 332725454 usage to BS0 to slice eMBB
# Client 881, coordinates : (404, 153) connected to slice eMBB @ BS0
# Client_881, coordinates : (404, 153) requests 486261698 usage to BS0 to slice eMBB
# Client 890, coordinates : (237, 424) connection refused to slice URLLC @ BS0
# Client_890, coordinates : (237, 424) requests 7683695 usage to BS0 to slice URLLC
# Client 438, coordinates : (118, 215) connection refused to slice voice @ BS0
# Client_438, coordinates : (118, 215) requests 6639615 usage to BS0 to slice voice
# Client 756, coordinates : (365, 60) connected to slice eMBB @ BS0
# Client_756, coordinates : (365, 60) requests 458313164 usage to BS0 to slice eMBB
# Client 93, coordinates : (333, 162) connection refused to slice voice @ BS0
# Client_93, coordinates : (333, 162) requests 5283524 usage to BS0 to slice voice
# Client 495, coordinates : (284, 287) connected to slice eMBB @ BS0
# Client_495, coordinates : (284, 287) requests 149117283 usage to BS0 to slice eMBB
# Client 439, coordinates : (520, 175) connected to slice eMBB @ BS0
# Client_439, coordinates : (520, 175) requests 361721849 usage to BS0 to slice eMBB
# Client 761, coordinates : (290, 314) connected to slice eMBB @ BS0
# Client_761, coordinates : (290, 314) requests 102264408 usage to BS0 to slice eMBB
# Client 406, coordinates : (531, 120) connection refused to slice voice @ BS0
# Client_406, coordinates : (531, 120) requests 4061608 usage to BS0 to slice voice
# Client 504, coordinates : (155, 446) connected to slice eMBB @ BS0
# Client_504, coordinates : (155, 446) requests 351163114 usage to BS0 to slice eMBB
# Client 56, coordinates : (472, 526) connection refused to slice URLLC @ BS0
# Client_56, coordinates : (472, 526) requests 7973854 usage to BS0 to slice URLLC
# Client 76, coordinates : (140, 101) connected to slice mMTC @ BS0
# Client_76, coordinates : (140, 101) requests 6532854 usage to BS0 to slice mMTC
# Client 916, coordinates : (440, 114) connection refused to slice URLLC @ BS0
# Client_916, coordinates : (440, 114) requests 7459393 usage to BS0 to slice URLLC
# Client 403, coordinates : (52, 498) connection refused to slice MIoT @ BS0
# Client_403, coordinates : (52, 498) requests 5337136 usage to BS0 to slice MIoT
# Client 466, coordinates : (131, 135) connected to slice eMBB @ BS0
# Client_466, coordinates : (131, 135) requests 270659066 usage to BS0 to slice eMBB
# Client 776, coordinates : (118, 91) connected to slice eMBB @ BS0
# Client_776, coordinates : (118, 91) requests 280685854 usage to BS0 to slice eMBB
# Client 154, coordinates : (86, 501) connected to slice eMBB @ BS0
# Client_154, coordinates : (86, 501) requests 94961039 usage to BS0 to slice eMBB
# Client 456, coordinates : (252, 537) connection refused to slice URLLC @ BS0
# Client_456, coordinates : (252, 537) requests 5612678 usage to BS0 to slice URLLC
# Client 946, coordinates : (412, 208) connection refused to slice voice @ BS0
# Client_946, coordinates : (412, 208) requests 6413790 usage to BS0 to slice voice
# Client 762, coordinates : (86, 145) connected to slice eMBB @ BS0
# Client_762, coordinates : (86, 145) requests 149425578 usage to BS0 to slice eMBB
# Client 462, coordinates : (223, 119) connected to slice eMBB @ BS0
# Client_462, coordinates : (223, 119) requests 375960156 usage to BS0 to slice eMBB
# Client 222, coordinates : (70, 160) connected to slice eMBB @ BS0
# Client_222, coordinates : (70, 160) requests 84055089 usage to BS0 to slice eMBB
# Client 620, coordinates : (427, 208) connection refused to slice URLLC @ BS0
# Client_620, coordinates : (427, 208) requests 5443497 usage to BS0 to slice URLLC
# Client 253, coordinates : (480, 478) connected to slice eMBB @ BS0
# Client_253, coordinates : (480, 478) requests 227792680 usage to BS0 to slice eMBB
# Client 47, coordinates : (318, 493) connection refused to slice voice @ BS0
# Client_47, coordinates : (318, 493) requests 6176450 usage to BS0 to slice voice
# Client 392, coordinates : (285, 152) connection refused to slice voice @ BS0
# Client_392, coordinates : (285, 152) requests 5701598 usage to BS0 to slice voice
# Client 755, coordinates : (540, 54) connected to slice eMBB @ BS0
# Client_755, coordinates : (540, 54) requests 330709095 usage to BS0 to slice eMBB
# Client 915, coordinates : (342, 100) connected to slice mMTC @ BS0
# Client_915, coordinates : (342, 100) requests 5020778 usage to BS0 to slice mMTC
# Client 699, coordinates : (118, 280) connection refused to slice MIoT @ BS0
# Client_699, coordinates : (118, 280) requests 2438393 usage to BS0 to slice MIoT
# Client 94, coordinates : (221, 279) connection refused to slice URLLC @ BS0
# Client_94, coordinates : (221, 279) requests 6785162 usage to BS0 to slice URLLC
# Client 709, coordinates : (113, 154) connection refused to slice voice @ BS0
# Client_709, coordinates : (113, 154) requests 4168653 usage to BS0 to slice voice
# Client 359, coordinates : (410, 254) connection refused to slice URLLC @ BS0
# Client_359, coordinates : (410, 254) requests 7409420 usage to BS0 to slice URLLC
# Client 301, coordinates : (284, 336) connection refused to slice URLLC @ BS0
# Client_301, coordinates : (284, 336) requests 6273114 usage to BS0 to slice URLLC
# Client 124, coordinates : (306, 169) connection refused to slice voice @ BS0
# Client_124, coordinates : (306, 169) requests 7628726 usage to BS0 to slice voice
# Client 311, coordinates : (376, 465) connected to slice eMBB @ BS0
# Client_311, coordinates : (376, 465) requests 268392706 usage to BS0 to slice eMBB
# Client 905, coordinates : (376, 146) connected to slice mMTC @ BS0
# Client_905, coordinates : (376, 146) requests 2169137 usage to BS0 to slice mMTC
# Client 553, coordinates : (543, 202) connected to slice eMBB @ BS0
# Client_553, coordinates : (543, 202) requests 57031279 usage to BS0 to slice eMBB
# Client 523, coordinates : (56, 506) connected to slice eMBB @ BS0
# Client_523, coordinates : (56, 506) requests 205995518 usage to BS0 to slice eMBB
# Client 889, coordinates : (409, 396) connected to slice eMBB @ BS0
# Client_889, coordinates : (409, 396) requests 251601760 usage to BS0 to slice eMBB
# Client 185, coordinates : (385, 432) connection refused to slice voice @ BS0
# Client_185, coordinates : (385, 432) requests 7362460 usage to BS0 to slice voice
# Client 265, coordinates : (252, 414) connection refused to slice URLLC @ BS0
# Client_265, coordinates : (252, 414) requests 7988942 usage to BS0 to slice URLLC
# Client 582, coordinates : (215, 131) connection refused to slice URLLC @ BS0
# Client_582, coordinates : (215, 131) requests 7147675 usage to BS0 to slice URLLC
# Client 339, coordinates : (179, 132) connection refused to slice voice @ BS0
# Client_339, coordinates : (179, 132) requests 6998117 usage to BS0 to slice voice
# ...
# Client 362, coordinates: (131, 257), releases 4207126 usage to BS0
# Client 70, coordinates: (513, 80), releases 100000000 usage to BS0
# Client 881, coordinates: (428.43566579625934, 135.89598526848988), releases 100000000 usage to BS0
# Client 635, coordinates: (190.96086416626787, 92.07600350517377), releases 278223 usage to BS0
# Client 635, coordinates: (190.96086416626787,92.07600350517377) disconnected from slice MIoT @ BS0
# Client 373, coordinates: (347, 172), releases 1000000 usage to BS0
# Client 251, coordinates: (400, 407), releases 100000000 usage to BS0
# Client 830, coordinates: (432.3436158964697, 142.77590875812527), releases 123334 usage to BS0
# Client 830, coordinates: (432.3436158964697,142.77590875812527) disconnected from slice URLLC @ BS0
# Client 229, coordinates: (310.1842771991644, 477.0807060264548), releases 1000000 usage to BS0
# Client 360, coordinates: (417.05299970070365, 318.5416092359875), releases 1000000 usage to BS0
# Client 490, coordinates: (355.2179079344104, 116.82826621439071), releases 2066194 usage to BS0
# Client 490, coordinates: (355.2179079344104,116.82826621439071) disconnected from slice mMTC @ BS0
# Client 828, coordinates: (498, 93), releases 1000000 usage to BS0
# Client 292, coordinates: (212, 271), releases 54578 usage to BS0
# Client 292, coordinates: (212,271) disconnected from slice MIoT @ BS0
# Client 489, coordinates: (70.49762435511123, 291.32985237732476), releases 100000000 usage to BS0
# Client 772, coordinates: (222, 143), releases 100000000 usage to BS0
# Client 912, coordinates: (475, 117), releases 2733779 usage to BS0
# Client 439, coordinates: (529, 186), releases 100000000 usage to BS0
# Client 812, coordinates: (269.9416906820583, 119.6488406789788), releases 94403270 usage to BS0
# Client 812, coordinates: (269.9416906820583,119.6488406789788) disconnected from slice eMBB @ BS0
# Client 519, coordinates: (222, 158), releases 100000000 usage to BS0
# Client 834, coordinates: (471, 354), releases 1000000 usage to BS0
# Client 883, coordinates: (256.84904841962765, 452.2463048201789), releases 574736 usage to BS0
# Client 883, coordinates: (256.84904841962765,452.2463048201789) disconnected from slice MIoT @ BS0
# Client 845, coordinates: (117, 94), releases 395108 usage to BS0
# Client 845, coordinates: (117,94) disconnected from slice mMTC @ BS0
# Client 65, coordinates: (127, 314), releases 51792012 usage to BS0
# Client 65, coordinates: (127,314) disconnected from slice eMBB @ BS0
# Client 781, coordinates: (57, 486), releases 1663142 usage to BS0
# Client 781, coordinates: (57,486) disconnected from slice MIoT @ BS0
# Client 899, coordinates: (122.98948716777994, 142.10658749511524), releases 100000000 usage to BS0
# Client 202, coordinates: (345.43714448836715, 465.638808823411), releases 100000000 usage to BS0
# Client 641, coordinates: (419.5788279290924, 213.75570107164182), releases 1000000 usage to BS0
# Client 702, coordinates: (365, 210), releases 1021024 usage to BS0
# Client 702, coordinates: (365,210) disconnected from slice URLLC @ BS0
# Client 353, coordinates: (409, 515), releases 2555489 usage to BS0
# Client 9, coordinates: (455.530338689083, 103.65308587963499), releases 1000000 usage to BS0
# Client 129, coordinates: (411, 207), releases 2089871 usage to BS0
# Client 129, coordinates: (411,207) disconnected from slice mMTC @ BS0
# Client 186, coordinates: (192.29922114783696, 393.8049462127973), releases 1440060 usage to BS0
# Client 186, coordinates: (192.29922114783696,393.8049462127973) disconnected from slice mMTC @ BS0
# Client 725, coordinates: (510, 302), releases 100000000 usage to BS0
# Client 395, coordinates: (168.52810727722712, 280.13862322341856), releases 1826570 usage to BS0
# Client 395, coordinates: (168.52810727722712,280.13862322341856) disconnected from slice MIoT @ BS0
# Client 911, coordinates: (78.22552755272855, 492.35110002081825), releases 43913402 usage to BS0
# Client 911, coordinates: (78.22552755272855,492.35110002081825) disconnected from slice eMBB @ BS0
# Client 854, coordinates: (261.8509319073848, 76.41048762538959), releases 1000000 usage to BS0
# Client 662, coordinates: (411, 494), releases 46517204 usage to BS0
# Client 662, coordinates: (411,494) disconnected from slice eMBB @ BS0
# Client 650, coordinates: (85, 101), releases 1000000 usage to BS0
# Client 420, coordinates: (376, 443), releases 3916223 usage to BS0
# Client 420, coordinates: (376,443) disconnected from slice mMTC @ BS0
# Client 398, coordinates: (270, 288), releases 1000000 usage to BS0
# Client 545, coordinates: (517, 427), releases 100000000 usage to BS0
# Client 356, coordinates: (293, 218), releases 5292836 usage to BS0
# Client 484, coordinates: (81, 398), releases 1000000 usage to BS0
# Client 838, coordinates: (253, 530), releases 970589 usage to BS0
# Client 838, coordinates: (253,530) disconnected from slice MIoT @ BS0
# Client 60, coordinates: (464, 400), releases 2356189 usage to BS0
# Client 60, coordinates: (464,400) disconnected from slice mMTC @ BS0
# Client 173, coordinates: (355, 218), releases 88694 usage to BS0
# Client 173, coordinates: (355,218) disconnected from slice MIoT @ BS0
# Client 636, coordinates: (168, 445), releases 1000000 usage to BS0
# Client 307, coordinates: (178, 216), releases 588750 usage to BS0
# Client 307, coordinates: (178,216) disconnected from slice URLLC @ BS0
# Client 376, coordinates: (212.86322479349514, 100.09204957848216), releases 2671648 usage to BS0
# Client 585, coordinates: (497, 308), releases 1000000 usage to BS0
# Client 843, coordinates: (244, 233), releases 1000000 usage to BS0
# Client 504, coordinates: (154, 449), releases 100000000 usage to BS0
# Client 91, coordinates: (334.7914186079589, 541.1004346160148), releases 100000000 usage to BS0
# Client 477, coordinates: (398, 329), releases 1000000 usage to BS0
# Client 816, coordinates: (347, 295), releases 1000000 usage to BS0
# Client 776, coordinates: (119, 84), releases 100000000 usage to BS0
# Client 113, coordinates: (177.34474743908658, 173.86047835643794), releases 94923760 usage to BS0
# Client 113, coordinates: (177.34474743908658,173.86047835643794) disconnected from slice eMBB @ BS0
# Client 314, coordinates: (460.39402867529424, 524.3875564956032), releases 1000000 usage to BS0
# Client 878, coordinates: (326, 487), releases 1000000 usage to BS0
# Client 580, coordinates: (153, 514), releases 1052200 usage to BS0
# Client 580, coordinates: (153,514) disconnected from slice MIoT @ BS0
# Client 791, coordinates: (514, 386), releases 1000000 usage to BS0
# Client 275, coordinates: (152.52675708938287, 444.4104544112902), releases 100000000 usage to BS0
# Client 460, coordinates: (110, 338), releases 43407653 usage to BS0
# Client 460, coordinates: (110,338) disconnected from slice eMBB @ BS0
# Client 938, coordinates: (136, 78), releases 19188138 usage to BS0
# Client 938, coordinates: (136,78) disconnected from slice eMBB @ BS0
# Client 464, coordinates: (252, 295), releases 100000000 usage to BS0
# Client 933, coordinates: (65.22337069317756, 146.12217835070055), releases 100000000 usage to BS0
# Client 550, coordinates: (474, 62), releases 1000000 usage to BS0
# Client 756, coordinates: (373, 59), releases 100000000 usage to BS0
# Client 110, coordinates: (340, 57), releases 100000000 usage to BS0
# Client 817, coordinates: (339, 123), releases 100000000 usage to BS0
# Client 547, coordinates: (256, 124), releases 71414447 usage to BS0
# Client 547, coordinates: (256,124) disconnected from slice eMBB @ BS0
# Client 27, coordinates: (217, 238), releases 1000000 usage to BS0
# Client 874, coordinates: (475, 505), releases 1000000 usage to BS0
# Client 98, coordinates: (128.2378229171863, 292.9098462384191), releases 1000000 usage to BS0
# Client 438, coordinates: (130, 226), releases 1000000 usage to BS0
# Client 277, coordinates: (395, 417), releases 1000000 usage to BS0
# Client 602, coordinates: (180, 73), releases 1128761 usage to BS0
# Client 602, coordinates: (180,73) disconnected from slice MIoT @ BS0
# Client 12, coordinates: (434.2384112319496, 256.1598511093858), releases 100000000 usage to BS0
# Client 815, coordinates: (101.88638500368776, 89.29487464895196), releases 100000000 usage to BS0
# Client 339, coordinates: (176, 139), releases 1000000 usage to BS0
# Client 445, coordinates: (549, 352), releases 1000000 usage to BS0
# Client 494, coordinates: (351, 135), releases 323489 usage to BS0
# Client 494, coordinates: (351,135) disconnected from slice mMTC @ BS0
# Client 893, coordinates: (204, 208), releases 1000000 usage to BS0
# Client 617, coordinates: (57, 102), releases 100000000 usage to BS0
# Client 715, coordinates: (380.5349365442209, 430.45547315692886), releases 100000000 usage to BS0
# Client 677, coordinates: (95, 303), releases 1563737 usage to BS0
# Client 677, coordinates: (95,303) disconnected from slice MIoT @ BS0
# Client 260, coordinates: (204.91013814588425, 145.8575928392644), releases 100000000 usage to BS0
# Client 701, coordinates: (485.70740611497325, 272.34077840056403), releases 6799850 usage to BS0
# Client 754, coordinates: (383.6033566042233, 510.9663949362995), releases 660054 usage to BS0
# Client 754, coordinates: (383.6033566042233,510.9663949362995) disconnected from slice URLLC @ BS0
# Client 642, coordinates: (144.97737885965302, 107.91895112828753), releases 795429 usage to BS0
# Client 642, coordinates: (144.97737885965302,107.91895112828753) disconnected from slice URLLC @ BS0
# Client 341, coordinates: (516, 69), releases 6516523 usage to BS0
# Client 632, coordinates: (488.8387876162207, 137.42408990101663), releases 1000000 usage to BS0
# Client 466, coordinates: (132, 134), releases 100000000 usage to BS0
# Client 704, coordinates: (310.72549776449773, 250.27493537075478), releases 2555489 usage to BS0
# Client 813, coordinates: (62, 142), releases 100000000 usage to BS0
# Client 253, coordinates: (493, 487), releases 100000000 usage to BS0
# Client 90, coordinates: (222, 91), releases 5598527 usage to BS0
# Client 90, coordinates: (222,91) disconnected from slice URLLC @ BS0
# Client 7, coordinates: (491, 105), releases 4687940 usage to BS0
# Client 826, coordinates: (453, 327), releases 100000000 usage to BS0
# Client 336, coordinates: (251, 125), releases 6516523 usage to BS0
# Client 285, coordinates: (456, 339), releases 100000000 usage to BS0
# Client 988, coordinates: (175, 261), releases 2154868 usage to BS0
# Client 988, coordinates: (175,261) disconnected from slice MIoT @ BS0
# Client 262, coordinates: (469.78155761905066, 309.8501159450858), releases 2903855 usage to BS0
# Client 262, coordinates: (469.78155761905066,309.8501159450858) disconnected from slice mMTC @ BS0
# Client 510, coordinates: (314, 94), releases 6516523 usage to BS0
# Client 40, coordinates: (198, 325), releases 100000000 usage to BS0
# Client 487, coordinates: (252.07828658331712, 321.4955642270524), releases 2555489 usage to BS0
# Client 541, coordinates: (374, 251), releases 6516523 usage to BS0
# Client 567, coordinates: (344.05047161454297, 139.70012893112136), releases 6516523 usage to BS0
# Client 19, coordinates: (482.55551489261165, 131.48946527947865), releases 6516523 usage to BS0
# Client 170, coordinates: (308, 354), releases 6516523 usage to BS0
# Client 764, coordinates: (78, 178), releases 6516523 usage to BS0
# Client 299, coordinates: (365, 553), releases 1228828 usage to BS0
# Client 299, coordinates: (365,553) disconnected from slice MIoT @ BS0
# Client 930, coordinates: (217, 332), releases 4687940 usage to BS0
# Client 521, coordinates: (308, 244), releases 4687940 usage to BS0
# Client 109, coordinates: (493, 484), releases 100000000 usage to BS0
# Client 13, coordinates: (159, 463), releases 100000000 usage to BS0
# Client 796, coordinates: (377, 368), releases 31250952 usage to BS0
# Client 796, coordinates: (377,368) disconnected from slice eMBB @ BS0
# Client 523, coordinates: (56, 500), releases 100000000 usage to BS0
# Client 690, coordinates: (271, 371), releases 1000000 usage to BS0
# Client 609, coordinates: (539, 257), releases 2555489 usage to BS0
# Client 190, coordinates: (178, 522), releases 100000000 usage to BS0
# Client 234, coordinates: (230.0163384111777, 423.2621362620489), releases 3591275 usage to BS0
# Client 234, coordinates: (230.0163384111777,423.2621362620489) disconnected from slice mMTC @ BS0
# Client 424, coordinates: (511, 212), releases 1000000 usage to BS0
# Client 590, coordinates: (55, 379), releases 2555489 usage to BS0
# Client 862, coordinates: (446.0856941163761, 351.77488491911765), releases 3507347 usage to BS0
# Client 862, coordinates: (446.0856941163761,351.77488491911765) disconnected from slice mMTC @ BS0
# Client 461, coordinates: (427.56699996099445, 534.5469929620659), releases 1000000 usage to BS0
# Client 334, coordinates: (328.85512196224056, 302.0737581530664), releases 4687940 usage to BS0
# Client 889, coordinates: (393.59940808168244, 379.9390043652333), releases 100000000 usage to BS0
# Client 535, coordinates: (402, 277), releases 8176444 usage to BS0
# Client 535, coordinates: (402,277) disconnected from slice eMBB @ BS0
# Client 380, coordinates: (528, 529), releases 2555489 usage to BS0
# Client 1, coordinates: (148, 395), releases 1971726 usage to BS0
# Client 1, coordinates: (148,395) disconnected from slice MIoT @ BS0
# Client 572, coordinates: (299, 405), releases 54157707 usage to BS0
# Client 572, coordinates: (299,405) disconnected from slice eMBB @ BS0
# Client 621, coordinates: (283, 310), releases 1000000 usage to BS0
# Client 305, coordinates: (341, 318), releases 100000000 usage to BS0
# Client 224, coordinates: (162, 503), releases 2555489 usage to BS0
# Client 355, coordinates: (521, 533), releases 1000000 usage to BS0
# Client 76, coordinates: (121, 103), releases 4687940 usage to BS0
# Client 154, coordinates: (82, 504), releases 100000000 usage to BS0
# Client 618, coordinates: (407, 409), releases 2555489 usage to BS0
# Client 23, coordinates: (443.689362539127, 320.05989906637683), releases 2265728 usage to BS0
# Client 23, coordinates: (443.689362539127,320.05989906637683) disconnected from slice MIoT @ BS0
# Client 712, coordinates: (20.087107409296305, 518.2340426964636), releases 646953 usage to BS0
# Client 712, coordinates: (20.087107409296305,518.2340426964636) disconnected from slice mMTC @ BS0
# Client 175, coordinates: (242, 292), releases 1000000 usage to BS0
# Client 807, coordinates: (411, 518), releases 21938731 usage to BS0
# Client 807, coordinates: (411,518) disconnected from slice eMBB @ BS0
# Client 605, coordinates: (174.9304035333583, 180.91126837927027), releases 100000000 usage to BS0
# Client 773, coordinates: (377, 285), releases 1000000 usage to BS0
# Client 875, coordinates: (322, 395), releases 1000000 usage to BS0
# Client 382, coordinates: (245, 481), releases 4687940 usage to BS0
# Client 692, coordinates: (307, 278), releases 100000000 usage to BS0
# Client 929, coordinates: (228.2881871717239, 524.9348371091346), releases 1097281 usage to BS0
# Client 929, coordinates: (228.2881871717239,524.9348371091346) disconnected from slice MIoT @ BS0
# Client 966, coordinates: (63, 452), releases 2555489 usage to BS0
# Client 544, coordinates: (389, 253), releases 1000000 usage to BS0
# Client 196, coordinates: (348, 145), releases 2555489 usage to BS0
# Client 500, coordinates: (423.86101231909504, 277.459168471931), releases 4687940 usage to BS0
# Client 281, coordinates: (116, 535), releases 3405319 usage to BS0
# Client 281, coordinates: (116,535) disconnected from slice mMTC @ BS0
# Client 177, coordinates: (446,550) disconnected from slice MIoT @ BS0
# Client 299, coordinates: (365,553) disconnected from slice MIoT @ BS0
# Client 87, coordinates: (74.08299243429775,25.980072490754175) disconnected from slice eMBB @ BS0
# Client 606, coordinates: (485,48) disconnected from slice MIoT @ BS0
# Client 693, coordinates: (550,393) disconnected from slice eMBB @ BS0
# Client 992, coordinates: (63,48) disconnected from slice voice @ BS0
# Client 199, coordinates: (45,246) disconnected from slice eMBB @ BS0
# Client 729, coordinates: (587.6997536036666,276.2859089191567) disconnected from slice MIoT @ BS0

# %%
with open('new_data.csv', mode='w') as csv_file:
    fieldnames = ['embb_rate', 'embb_users', 'embb_req', 'urllc_rate', 'urllc_users', 'urllc_req', 'miot_rate', 'miot_users', 'miot_req', 'mmtc_rate', 'mmtc_users', 'mmtc_req', 'voice_rate', 'voice_users', 'voice_req']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    writer.writeheader()
    for item in csv_final:
        writer.writerow({'embb_rate': item.g_embb, 'embb_users': item.connect_embb, 'embb_req': item.r_embb, 'urllc_rate': item.g_urllc, 'urllc_users': item.connect_urllc, 'urllc_req': item.r_urllc, 'miot_rate': item.g_miot, 'miot_users': item.connect_miot, 'miot_req': item.r_miot, 'mmtc_rate': item.g_mmtc, 'mmtc_users': item.connect_mmtc, 'mmtc_req': item.r_mmtc, 'voice_rate': item.g_voice, 'voice_users': item.connect_voice, 'voice_req': item.r_voice})

# %%
for item in csv_final:
    print(item.r_urllc, item.connect_urllc)
# Out:
# 0 0
# 52804629 8
# 196739148 35
# 118115232 38
# 185898972 36
# 126935269 36
# 126190269 30
# 165437719 38
# 120650212 32
# 94617048 25
# 145813224 26
# 159065851 30
# 139701514 29
# 72090359 21
# 183414228 31
# 107355609 22
# 152448253 29
# 154322373 34
# 130182038 33
# 51888623 20
# 147624234 25
# 135001748 26
# 108904488 24
# 109007700 21
# 97190920 20
# 129742250 20
# 103343185 24
# 41496801 12
# 160770037 25
# 83266460 18
